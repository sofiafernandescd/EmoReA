# %% [markdown]
# # Set of Experiments
# Goals: minimizing latency and maximizing benchmark performance, while using lightweight components where possible.
#
#
#
# ## ⚙️ General Implementation Setup
#
# Environment: Python 3.10+, TensorFlow/Keras or PyTorch, scikit-learn, HuggingFace Transformers, DeepFace, OpenSMILE, librosa.
#
# Evaluation Split: Stratified Shuffle Split (70% train, 30% test).
#
# Metrics Across All Tasks:
# - Accuracy
# - F1-Score (macro): Handles emotion class imbalance.
# - Latency (ms/sample or s/batch)
# - Model Size (MB)
# - Confusion Matrix for qualitative insights.
#
#
#  Datasets: RAVDESS, EmoDB, TESS (CREMA-D optional; map to shared label space)
#
# Labels: Anger, Disgust, Fear, Happiness, Sadness, Surprise, Neutral

# %%
import sys
import os
# insert the path to the source code directory
module_path = os.path.abspath(os.path.join('..', '..')) 
sys.path.insert(0, module_path)

from src.utils import load_emodb, load_ravdess, load_tess, load_crema_d, filter_emotions

import numpy as np
import pandas as pd

emodb = filter_emotions(load_emodb())
ravdess = filter_emotions(load_ravdess())
tess = filter_emotions(load_tess())
#crema = filter_emotions(load_crema_d())

# add a dataset column to each dataset
emodb['dataset'] = 'emodb'
ravdess['dataset'] = 'ravdess'
tess['dataset'] = 'tess'
#crema['dataset'] = 'crema'

# concatenate all datasets
df = pd.concat([emodb, ravdess, tess], ignore_index=True)
# shuffle the dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)


# save the dataset to a csv file
output_file = 'combined_emotion_dataset.csv'
df.to_csv(output_file, index=False)

# plot the distribution of emotions
df['label'].value_counts().plot(kind='bar', title='Emotion Distribution')
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.12)
# Path to dataset files: /Users/sofiafernandes/.cache/kagglehub/datasets/piyushagni5/berlin-database-of-emotional-speech-emodb/versions/1
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.12)
# Path to dataset files: /Users/sofiafernandes/.cache/kagglehub/datasets/uwrfkaggler/ravdess-emotional-speech-audio/versions/1
# ['Actor_16', 'Actor_11', 'Actor_18', 'Actor_20', 'Actor_21', 'Actor_19', 'Actor_10', 'Actor_17', 'Actor_04', 'Actor_03', 'Actor_02', 'Actor_05', 'audio_speech_actors_01-24', 'Actor_12', 'Actor_15', 'Actor_23', 'Actor_24', 'Actor_22', 'Actor_14', 'Actor_13', 'Actor_09', 'Actor_07', 'Actor_06', 'Actor_01', 'Actor_08']
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.12)
# Path to dataset files: /Users/sofiafernandes/.cache/kagglehub/datasets/ejlok1/toronto-emotional-speech-set-tess/versions/1
# ['TESS']
# ['YAF_disgust', 'OAF_Pleasant_surprise', 'OAF_happy', 'YAF_sad', 'YAF_happy', 'YAF_neutral', 'OAF_Fear', 'OAF_angry', 'YAF_pleasant_surprised', 'YAF_fear', 'OAF_neutral', 'OAF_disgust', 'YAF_angry', 'OAF_Sad']
# <Axes: title={'center': 'Emotion Distribution'}, xlabel='label'>

# %%
load_emodb()['label'].value_counts()
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.12)
# Path to dataset files: /Users/sofiafernandes/.cache/kagglehub/datasets/piyushagni5/berlin-database-of-emotional-speech-emodb/versions/1
# label
# angry      127
# boredom     81
# neutral     79
# happy       71
# fear        69
# sad         62
# disgust     46
# Name: count, dtype: int64

# %%
# OpenSMILE feature extraction
# https://audeering.github.io/opensmile-python/
#!pip install opensmile

import opensmile

def extract_features_opensmile():
    """ Extract features from the individual datasets using OpenSMILE.
    This function processes the EMO-DB, RAVDESS, TESS, and CREMA-D datasets
    and saves the extracted features to CSV files.
    """
    # Load data and extract features
    smile = opensmile.Smile(
        feature_set=opensmile.FeatureSet.GeMAPSv01b,
        #feature_set=opensmile.FeatureSet.eGeMAPSv02,
        feature_level=opensmile.FeatureLevel.Functionals,
    )

    feats_emodb = smile.process_files(emodb["filename"])
    feats_emodb.to_csv('emodb_features.csv', index=False)

    feats_ravdess = smile.process_files(ravdess["filename"])
    feats_ravdess.to_csv('ravdess_features.csv', index=False)

    feats_tess = smile.process_files(tess["filename"])
    feats_tess.to_csv('tess_features.csv', index=False)

    #feats_crema = smile.process_files(crema["filename"])
    #feats_crema.to_csv('crema_features.csv', index=False)

#extract_features_opensmile()
feats_df = pd.read_csv('combined_df_features.csv')
feats_emodb = pd.read_csv('emodb_features.csv')
feats_ravdess = pd.read_csv('ravdess_features.csv')
feats_tess = pd.read_csv('tess_features.csv')
#feats_crema = pd.read_csv('crema_features.csv')

# %%
# Load data and extract features
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    #feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
)

#feats_df = smile.process_files(df["filename"])
feats_df = pd.read_csv('combined_df_features.csv')
# save the features to a csv file
#feats_df.to_csv('combined_df_features.csv', index=False)

feats_df.head()
# Out:
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          35.420020                                0.122371
# 1                          41.707138                                0.075898
# 2                          40.058247                                0.045866
# 3                          42.324272                                0.074393
# 4                          34.454590                                0.087642
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                   31.292658
# 1                                   39.588448
# 2                                   38.880238
# 3                                   40.107723
# 4                                   31.992432
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   35.643230
# 1                                   41.946426
# 2                                   39.709380
# 3                                   41.854042
# 4                                   33.751865
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                   39.118300
# 1                                   43.430430
# 2                                   41.036660
# 3                                   45.533787
# 4                                   37.750618
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                  7.825643
# 1                                  3.841984
# 2                                  2.156422
# 3                                  5.426063
# 4                                  5.758186
#
#    F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                    35.614376
# 1                                    70.114395
# 2                                   139.598180
# 3                                    88.594280
# 4                                   107.164050
#
#    F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                      50.453495
# 1                                      76.713730
# 2                                     143.688550
# 3                                      43.917896
# 4                                     149.074230
#
#    F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                     41.440994
# 1                                     49.860855
# 2                                     58.721115
# 3                                     26.804290
# 4                                     20.824293
#
#    F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                       15.520793  ...
# 1                                       54.977875  ...
# 2                                       68.797100  ...
# 3                                       30.962640  ...
# 4                                        2.724423  ...
#
#    alphaRatioUV_sma3nz_amean  hammarbergIndexUV_sma3nz_amean  \
# 0                  -1.117758                       11.999436
# 1                   4.990377                        1.049555
# 2                 -14.412024                       23.928312
# 3                  -3.610666                       11.166558
# 4                  -7.613103                       15.695953
#
#    slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                   0.022039                      0.010847
# 1                  -0.013456                     -0.001773
# 2                  -0.061213                     -0.003443
# 3                  -0.052942                     -0.001891
# 4                   0.061815                      0.002180
#
#    loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0             1.803607              1.012146                    0.302000
# 1             3.296703              1.694915                    0.360000
# 2             2.547771              1.315789                    0.470000
# 3             2.453988              1.273885                    0.420000
# 4             1.881720              0.817439                    0.486667
#
#    StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                      0.268805                   0.553333
# 1                      0.231517                   0.203333
# 2                      0.220000                   0.176667
# 3                      0.180000                   0.226667
# 4                      0.145220                   0.535000
#
#    StddevUnvoicedSegmentLength
# 0                     0.414796
# 1                     0.016997
# 2                     0.040277
# 3                     0.144299
# 4                     0.438891
#
# [5 rows x 62 columns]

# %% [markdown]
# ## 🔊 4.4.1 Speech Emotion Recognition (SER)
#
# ### Experiment 1.1 – SVM Parameter Tuning
#
# Features:
# - OpenSMILE GeMAPS
# - librosa: MFCCs, chroma, pitch
#
# Grid Search Params:
#
# C: [0.1, 1, 10], kernel: [‘linear’, ‘rbf’], gamma: [0.01, 0.1, 1]
#
# Metrics: Accuracy, F1-macro, Latency (time to predict full test set)

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from joblib import dump, load

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    #('feature_selection', SelectKBest(f_classif, k=20)),  # Or whatever method you use
    ('svm', SVC(kernel='linear', C=1.0, probability=True))
])

# Fit the model
X = feats_df
y = df['label']
# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('feature_selection', SelectKBest(k=20)),
#                 ('svm', SVC(kernel='linear', probability=True))])

# %%
# perform grid search for hyperparameter tuning
from sklearn.model_selection import GridSearchCV
param_grid = {
    'svm__C': [0.1, 1.0, 10.0],
    'svm__gamma': ['scale'], #'auto'],
    'svm__kernel': ['rbf'], #['linear', 'rbf'],
    #'feature_selection__k': [30, 40, 50] #[10, 20, 30]
}
grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Save the best model
best_model = grid_search.best_estimator_
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score: ", grid_search.best_score_)
dump(best_model, 'ser_svm_model.joblib')
# Out:
# Best parameters found:  {'feature_selection__k': 40, 'svm__C': 10.0, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score:  0.858142455294354
# ['ser_svm_model.joblib']

# %% [markdown]
# Best parameters found:  {'feature_selection__k': 30, 'svm__C': 10.0, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score:  0.8454446205317838
#
# Best parameters found:  {'feature_selection__k': 40, 'svm__C': 10.0, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score:  0.858142455294354

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from seaborn import heatmap
import matplotlib.pyplot as plt

def evaluate_model(best_model, X_test, y_test):
    """ Evaluate the model on the test set and print the classification report, accuracy, and confusion matrix. """
    # Make predictions
    #y_pred = pipeline.predict(X_test)
    # or using the best model from grid search
    y_pred = best_model.predict(X_test)   
    # Print classification report
    print(classification_report(y_test, y_pred))
    # Print accuracy score
    print("Accuracy:", accuracy_score(y_test, y_pred))

    # Print confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 7))
    heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=df['label'].unique(), yticklabels=df['label'].unique())
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

best_model = load('ser_svm_model.joblib')
evaluate_model(best_model, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.88      0.92      0.90       216
#      disgust       0.87      0.85      0.86       191
#         fear       0.88      0.87      0.88       198
#        happy       0.79      0.80      0.80       199
#      neutral       0.96      0.91      0.94       173
#          sad       0.91      0.87      0.89       196
#     surprise       0.89      0.92      0.90       178
#
#     accuracy                           0.88      1351
#    macro avg       0.88      0.88      0.88      1351
# weighted avg       0.88      0.88      0.88      1351
#
# Accuracy: 0.8786084381939304

# %%
# Load features from disk
data = np.load('./features/iemocap_GeMAPS_features.npz')
print(data['X'].shape)  # Check available arrays in the file
X = data['X']
y = data['y']
# filter bothe to only include allowed emotions
allowed_emotions = ['happy', 'sad', 'angry', 'neutral', 'fear', 'surprise', 'disgust']
mask = np.isin(y, allowed_emotions)
X = X[mask]
y = y[mask]

evaluate_model(best_model, X, y)
# Out:
# (10039, 62)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#        angry       0.86      0.17      0.28      1269
#      disgust       0.00      0.00      0.00         2
#         fear       0.03      0.19      0.05       107
#        happy       0.14      0.33      0.20       656
#      neutral       0.42      0.12      0.18      1726
#          sad       0.44      0.40      0.42      1250
#     surprise       0.07      0.28      0.12       110
#
#     accuracy                           0.23      5120
#    macro avg       0.28      0.21      0.18      5120
# weighted avg       0.48      0.23      0.26      5120
#
# Accuracy: 0.2298828125

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# perform grid search for hyperparameter tuning
from sklearn.model_selection import GridSearchCV
param_grid = {
    'svm__C': [0.1, 1.0, 10.0],
    'svm__gamma': ['scale', 'auto'],
    'svm__kernel': ['rbf', 'linear'], #['linear', 'rbf'],
    'feature_selection__k': [20, 30, 40] #[10, 20, 30]
}
grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Save the best model
best_model = grid_search.best_estimator_
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score: ", grid_search.best_score_)
dump(best_model, 'ser_svm_model_iemocap.joblib')
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(

# %%
## EMO-DB dataset evaluation
emodb = df[df['dataset'] == 'emodb']
# collect idx of the EMO-DB dataset in the combined features dataframe
emodb_idx = [idx for idx in emodb.index if idx in y_test.index]
print(emodb_idx)
feats_emodb = feats_df.iloc[emodb_idx]
emodb_test = df.iloc[emodb_idx]
# Save the features to a csv file
feats_emodb.to_csv('emodb_test_features.csv', index=False)

X1 = feats_emodb
y1 = emodb_test['label']
# Split the dataset into training and testing sets
#X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.3, random_state=42, stratify=y1)
# Make predictions
evaluate_model(best_model, X1, y1)
# Out:
# [7, 41, 143, 168, 190, 225, 229, 262, 266, 317, 350, 393, 409, 429, 443, 452, 487, 515, 519, 545, 549, 559, 582, 726, 741, 786, 810, 815, 876, 911, 921, 948, 966, 1017, 1021, 1050, 1065, 1119, 1121, 1182, 1222, 1280, 1302, 1353, 1360, 1390, 1409, 1431, 1444, 1474, 1489, 1568, 1591, 1610, 1633, 1640, 1698, 1715, 1735, 1870, 1967, 2077, 2098, 2100, 2142, 2212, 2216, 2263, 2301, 2367, 2385, 2451, 2458, 2481, 2516, 2603, 2635, 2679, 2698, 2733, 2797, 2807, 2816, 2859, 2891, 2906, 2953, 2978, 3015, 3037, 3038, 3052, 3090, 3096, 3201, 3217, 3224, 3255, 3295, 3345, 3374, 3484, 3508, 3516, 3554, 3555, 3559, 3563, 3566, 3609, 3610, 3619, 3650, 3670, 3705, 3756, 3786, 3795, 3816, 3870, 3889, 3897, 3979, 4064, 4074, 4142, 4184, 4189, 4268, 4283, 4328, 4421, 4426, 4442, 4493]
#               precision    recall  f1-score   support
#
#        angry       0.75      0.93      0.83        43
#      disgust       0.83      0.71      0.77        14
#         fear       0.64      0.93      0.76        15
#        happy       0.77      0.37      0.50        27
#      neutral       0.86      0.83      0.84        23
#          sad       0.77      0.77      0.77        13
#
#     accuracy                           0.76       135
#    macro avg       0.77      0.76      0.75       135
# weighted avg       0.77      0.76      0.75       135
#
# Accuracy: 0.762962962962963

# %%
## RAVDESS dataset evaluation
ravdess = df[df['dataset'] == 'ravdess']
# collect idx of the RAVDESS dataset in the combined features dataframe
ravdess_idx = [idx for idx in ravdess.index if idx in y_test.index]
print(ravdess_idx)
feats_ravdess = feats_df.iloc[ravdess_idx]
ravdess_test = df.iloc[ravdess_idx]
# Save the features to a csv file
feats_ravdess.to_csv('ravdess_test_features.csv', index=False)  
X2 = feats_ravdess
y2 = ravdess_test['label']
# Make predictions
evaluate_model(best_model, X2, y2)


# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, GlobalMaxPooling1D, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# CNN: 1D + GlobalMaxPooling1D
# Define the model
def create_cnn_model(input_shape, num_classes):
    
    model = Sequential()
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(Dropout(0.1))

    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(Dropout(0.1))

    model.add(GlobalMaxPooling1D())
    
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.1))

    model.add(Dense(num_classes, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0003)  # menor lr para mais estabilidade
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return model
# Train on X_train, y_train
cnn_model = create_cnn_model((X_train.shape[1], 1), len(df['label'].unique()))
# add early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
# add a callback to save the best model
checkpoint = tf.keras.callbacks.ModelCheckpoint('ser_cnn_model.h5', monitor='val_loss', save_best_only=True, mode='min')
# add the checkpoint to the callbacks
callbacks = [early_stopping, checkpoint]
# learning rate scheduler
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-3 * 0.9 ** epoch, verbose=1)
callbacks.append(lr_scheduler)
# define learning rate as constant
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_reshaped = X_train_scaled.reshape(-1, X_train.shape[1], 1)
X_test_reshaped = X_test_scaled.reshape(-1, X_test.shape[1], 1)
# train the CNN model
cnn_model.fit(X_train_reshaped, y_train_encoded, epochs=1000, batch_size=16, validation_split=0.2, callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/1000
# 158/158 [==============================] - 3s 10ms/step - loss: 2.0345 - accuracy: 0.2996 - val_loss: 1.8522 - val_accuracy: 0.4184 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0009000000000000001.
# Epoch 2/1000
#  22/158 [===>..........................] - ETA: 1s - loss: 1.6648 - accuracy: 0.3636
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 158/158 [==============================] - 1s 9ms/step - loss: 1.5738 - accuracy: 0.4123 - val_loss: 1.6357 - val_accuracy: 0.5151 - lr: 9.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0008100000000000001.
# Epoch 3/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 1.4608 - accuracy: 0.4611 - val_loss: 1.4266 - val_accuracy: 0.5753 - lr: 8.1000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0007290000000000002.
# Epoch 4/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 1.3619 - accuracy: 0.5040 - val_loss: 1.3227 - val_accuracy: 0.5594 - lr: 7.2900e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0006561000000000001.
# Epoch 5/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 1.2925 - accuracy: 0.5397 - val_loss: 1.1993 - val_accuracy: 0.5848 - lr: 6.5610e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.00059049.
# Epoch 6/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 1.2161 - accuracy: 0.5675 - val_loss: 1.1673 - val_accuracy: 0.5975 - lr: 5.9049e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.000531441.
# Epoch 7/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 1.1716 - accuracy: 0.5869 - val_loss: 1.1208 - val_accuracy: 0.6149 - lr: 5.3144e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0004782969000000001.
# Epoch 8/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 1.1169 - accuracy: 0.5909 - val_loss: 1.0876 - val_accuracy: 0.6228 - lr: 4.7830e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0004304672100000001.
# Epoch 9/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 1.0802 - accuracy: 0.6063 - val_loss: 1.0661 - val_accuracy: 0.6181 - lr: 4.3047e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0003874204890000001.
# Epoch 10/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 1.0503 - accuracy: 0.6325 - val_loss: 1.0314 - val_accuracy: 0.6355 - lr: 3.8742e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0003486784401000001.
# Epoch 11/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 1.0311 - accuracy: 0.6321 - val_loss: 1.0110 - val_accuracy: 0.6498 - lr: 3.4868e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0003138105960900001.
# Epoch 12/1000
# 158/158 [==============================] - 2s 14ms/step - loss: 0.9903 - accuracy: 0.6480 - val_loss: 0.9967 - val_accuracy: 0.6640 - lr: 3.1381e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.
-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 3.090315438263264e-05.
# Epoch 34/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8261 - accuracy: 0.7040 - val_loss: 0.8701 - val_accuracy: 0.6815 - lr: 3.0903e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.7812838944369376e-05.
# Epoch 35/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8310 - accuracy: 0.7060 - val_loss: 0.8677 - val_accuracy: 0.6878 - lr: 2.7813e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.5031555049932436e-05.
# Epoch 36/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8058 - accuracy: 0.7246 - val_loss: 0.8693 - val_accuracy: 0.6910 - lr: 2.5032e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.2528399544939195e-05.
# Epoch 37/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7963 - accuracy: 0.7151 - val_loss: 0.8676 - val_accuracy: 0.6830 - lr: 2.2528e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.0275559590445276e-05.
# Epoch 38/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8130 - accuracy: 0.7163 - val_loss: 0.8687 - val_accuracy: 0.6910 - lr: 2.0276e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.824800363140075e-05.
# Epoch 39/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8123 - accuracy: 0.7052 - val_loss: 0.8641 - val_accuracy: 0.6846 - lr: 1.8248e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 1.6423203268260675e-05.
# Epoch 40/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8137 - accuracy: 0.7052 - val_loss: 0.8625 - val_accuracy: 0.6878 - lr: 1.6423e-05
#
# Epoch 41: LearningRateScheduler setting learning rate to 1.4780882941434608e-05.
# Epoch 41/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8017 - accuracy: 0.7095 - val_loss: 0.8636 - val_accuracy: 0.6941 - lr: 1.4781e-05
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.3302794647291146e-05.
# Epoch 42/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8109 - accuracy: 0.7067 - val_loss: 0.8648 - val_accuracy: 0.6926 - lr: 1.3303e-05
#
# Epoch 43: LearningRateScheduler setting learning rate to 1.1972515182562033e-05.
# Epoch 43/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8288 - accuracy: 0.7063 - val_loss: 0.8654 - val_accuracy: 0.6926 - lr: 1.1973e-05
#
# Epoch 44: LearningRateScheduler setting learning rate to 1.077526366430583e-05.
# Epoch 44/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8090 - accuracy: 0.7095 - val_loss: 0.8643 - val_accuracy: 0.6894 - lr: 1.0775e-05
#
# Epoch 45: LearningRateScheduler setting learning rate to 9.697737297875246e-06.
# Epoch 45/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8096 - accuracy: 0.7024 - val_loss: 0.8641 - val_accuracy: 0.6941 - lr: 9.6977e-06
#
# Epoch 46: LearningRateScheduler setting learning rate to 8.727963568087722e-06.
# Epoch 46/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8013 - accuracy: 0.7127 - val_loss: 0.8634 - val_accuracy: 0.6926 - lr: 8.7280e-06
#
# Epoch 47: LearningRateScheduler setting learning rate to 7.85516721127895e-06.
# Epoch 47/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7881 - accuracy: 0.7214 - val_loss: 0.8622 - val_accuracy: 0.6910 - lr: 7.8552e-06
#
# Epoch 48: LearningRateScheduler setting learning rate to 7.069650490151056e-06.
# Epoch 48/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.7960 - accuracy: 0.7202 - val_loss: 0.8615 - val_accuracy: 0.6878 - lr: 7.0697e-06
#
# Epoch 49: LearningRateScheduler setting learning rate to 6.36268544113595e-06.
# Epoch 49/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8083 - accuracy: 0.7060 - val_loss: 0.8628 - val_accuracy: 0.6894 - lr: 6.3627e-06
#
# Epoch 50: LearningRateScheduler setting learning rate to 5.726416897022355e-06.
# Epoch 50/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8146 - accuracy: 0.7190 - val_loss: 0.8603 - val_accuracy: 0.6894 - lr: 5.7264e-06
#
# Epoch 51: LearningRateScheduler setting learning rate to 5.15377520732012e-06.
# Epoch 51/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7910 - accuracy: 0.7063 - val_loss: 0.8603 - val_accuracy: 0.6926 - lr: 5.1538e-06
#
# Epoch 52: LearningRateScheduler setting learning rate to 4.638397686588108e-06.
# Epoch 52/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7883 - accuracy: 0.7187 - val_loss: 0.8608 - val_accuracy: 0.6926 - lr: 4.6384e-06
#
# Epoch 53: LearningRateScheduler setting learning rate to 4.174557917929297e-06.
# Epoch 53/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8104 - accuracy: 0.7151 - val_loss: 0.8594 - val_accuracy: 0.6910 - lr: 4.1746e-06
#
# Epoch 54: LearningRateScheduler setting learning rate to 3.7571021261363675e-06.
# Epoch 54/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8110 - accuracy: 0.7091 - val_loss: 0.8608 - val_accuracy: 0.6910 - lr: 3.7571e-06
#
# Epoch 55: LearningRateScheduler setting learning rate to 3.381391913522731e-06.
# Epoch 55/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7885 - accuracy: 0.7127 - val_loss: 0.8601 - val_accuracy: 0.6910 - lr: 3.3814e-06
#
# Epoch 56: LearningRateScheduler setting learning rate to 3.0432527221704577e-06.
# Epoch 56/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8044 - accuracy: 0.7079 - val_loss: 0.8613 - val_accuracy: 0.6926 - lr: 3.0433e-06
#
# Epoch 57: LearningRateScheduler setting learning rate to 2.7389274499534123e-06.
# Epoch 57/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7956 - accuracy: 0.7167 - val_loss: 0.8595 - val_accuracy: 0.6926 - lr: 2.7389e-06
#
# Epoch 58: LearningRateScheduler setting learning rate to 2.465034704958071e-06.
# Epoch 58/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8027 - accuracy: 0.7040 - val_loss: 0.8585 - val_accuracy: 0.6941 - lr: 2.4650e-06
#
# Epoch 59: LearningRateScheduler setting learning rate to 2.218531234462264e-06.
# Epoch 59/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7862 - accuracy: 0.7230 - val_loss: 0.8584 - val_accuracy: 0.6910 - lr: 2.2185e-06
#
# Epoch 60: LearningRateScheduler setting learning rate to 1.9966781110160375e-06.
# Epoch 60/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8131 - accuracy: 0.7139 - val_loss: 0.8587 - val_accuracy: 0.6910 - lr: 1.9967e-06
#
# Epoch 61: LearningRateScheduler setting learning rate to 1.797010299914434e-06.
# Epoch 61/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7934 - accuracy: 0.7159 - val_loss: 0.8590 - val_accuracy: 0.6926 - lr: 1.7970e-06
#
# Epoch 62: LearningRateScheduler setting learning rate to 1.6173092699229906e-06.
# Epoch 62/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7935 - accuracy: 0.7119 - val_loss: 0.8602 - val_accuracy: 0.6926 - lr: 1.6173e-06
#
# Epoch 63: LearningRateScheduler setting learning rate to 1.4555783429306915e-06.
# Epoch 63/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8086 - accuracy: 0.7087 - val_loss: 0.8588 - val_accuracy: 0.6926 - lr: 1.4556e-06
#
# Epoch 64: LearningRateScheduler setting learning rate to 1.3100205086376223e-06.
# Epoch 64/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7987 - accuracy: 0.7151 - val_loss: 0.8592 - val_accuracy: 0.6926 - lr: 1.3100e-06
#
# Epoch 65: LearningRateScheduler setting learning rate to 1.1790184577738603e-06.
# Epoch 65/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8068 - accuracy: 0.7028 - val_loss: 0.8583 - val_accuracy: 0.6926 - lr: 1.1790e-06
#
# Epoch 66: LearningRateScheduler setting learning rate to 1.061116611996474e-06.
# Epoch 66/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8022 - accuracy: 0.7147 - val_loss: 0.8593 - val_accuracy: 0.6926 - lr: 1.0611e-06
#
# Epoch 67: LearningRateScheduler setting learning rate to 9.550049507968267e-07.
# Epoch 67/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8055 - accuracy: 0.7163 - val_loss: 0.8591 - val_accuracy: 0.6926 - lr: 9.5500e-07
#
# Epoch 68: LearningRateScheduler setting learning rate to 8.595044557171441e-07.
# Epoch 68/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7944 - accuracy: 0.7131 - val_loss: 0.8592 - val_accuracy: 0.6926 - lr: 8.5950e-07
#
# Epoch 69: LearningRateScheduler setting learning rate to 7.735540101454298e-07.
# Epoch 69/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8003 - accuracy: 0.7103 - val_loss: 0.8593 - val_accuracy: 0.6894 - lr: 7.7355e-07
#
# Epoch 70: LearningRateScheduler setting learning rate to 6.961986091308867e-07.
# Epoch 70/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7921 - accuracy: 0.7171 - val_loss: 0.8597 - val_accuracy: 0.6910 - lr: 6.9620e-07
#
# Epoch 71: LearningRateScheduler setting learning rate to 6.265787482177981e-07.
# Epoch 71/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8092 - accuracy: 0.7067 - val_loss: 0.8591 - val_accuracy: 0.6910 - lr: 6.2658e-07
#
# Epoch 72: LearningRateScheduler setting learning rate to 5.639208733960184e-07.
# Epoch 72/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8107 - accuracy: 0.7063 - val_loss: 0.8599 - val_accuracy: 0.6910 - lr: 5.6392e-07
#
# Epoch 73: LearningRateScheduler setting learning rate to 5.075287860564166e-07.
# Epoch 73/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8009 - accuracy: 0.7111 - val_loss: 0.8594 - val_accuracy: 0.6910 - lr: 5.0753e-07
#
# Epoch 74: LearningRateScheduler setting learning rate to 4.5677590745077486e-07.
# Epoch 74/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8086 - accuracy: 0.7155 - val_loss: 0.8584 - val_accuracy: 0.6926 - lr: 4.5678e-07
#
# Epoch 75: LearningRateScheduler setting learning rate to 4.110983167056974e-07.
# Epoch 75/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8007 - accuracy: 0.7123 - val_loss: 0.8595 - val_accuracy: 0.6926 - lr: 4.1110e-07
#
# Epoch 76: LearningRateScheduler setting learning rate to 3.699884850351277e-07.
# Epoch 76/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8027 - accuracy: 0.7111 - val_loss: 0.8592 - val_accuracy: 0.6926 - lr: 3.6999e-07
#
# Epoch 77: LearningRateScheduler setting learning rate to 3.329896365316149e-07.
# Epoch 77/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7998 - accuracy: 0.7258 - val_loss: 0.8603 - val_accuracy: 0.6910 - lr: 3.3299e-07
#
# Epoch 78: LearningRateScheduler setting learning rate to 2.996906728784534e-07.
# Epoch 78/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7934 - accuracy: 0.7183 - val_loss: 0.8604 - val_accuracy: 0.6910 - lr: 2.9969e-07
#
# Epoch 79: LearningRateScheduler setting learning rate to 2.6972160559060813e-07.
# Epoch 79/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8036 - accuracy: 0.7079 - val_loss: 0.8598 - val_accuracy: 0.6910 - lr: 2.6972e-07
#
# Epoch 80: LearningRateScheduler setting learning rate to 2.427494450315473e-07.
# Epoch 80/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8017 - accuracy: 0.7095 - val_loss: 0.8593 - val_accuracy: 0.6926 - lr: 2.4275e-07
#
# Epoch 81: LearningRateScheduler setting learning rate to 2.1847450052839256e-07.
# Epoch 81/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7996 - accuracy: 0.7171 - val_loss: 0.8595 - val_accuracy: 0.6910 - lr: 2.1847e-07
#
# Epoch 82: LearningRateScheduler setting learning rate to 1.966270504755533e-07.
# Epoch 82/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8066 - accuracy: 0.7083 - val_loss: 0.8592 - val_accuracy: 0.6926 - lr: 1.9663e-07
#
# Epoch 83: LearningRateScheduler setting learning rate to 1.7696434542799797e-07.
# Epoch 83/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7995 - accuracy: 0.7079 - val_loss: 0.8609 - val_accuracy: 0.6926 - lr: 1.7696e-07
#
# Epoch 84: LearningRateScheduler setting learning rate to 1.5926791088519817e-07.
# Epoch 84/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7969 - accuracy: 0.7163 - val_loss: 0.8596 - val_accuracy: 0.6878 - lr: 1.5927e-07
#
# Epoch 85: LearningRateScheduler setting learning rate to 1.4334111979667837e-07.
# Epoch 85/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7942 - accuracy: 0.7234 - val_loss: 0.8618 - val_accuracy: 0.6957 - lr: 1.4334e-07
#
# Epoch 86: LearningRateScheduler setting learning rate to 1.2900700781701054e-07.
# Epoch 86/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8059 - accuracy: 0.7190 - val_loss: 0.8598 - val_accuracy: 0.6910 - lr: 1.2901e-07
#
# Epoch 87: LearningRateScheduler setting learning rate to 1.1610630703530949e-07.
# Epoch 87/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7967 - accuracy: 0.7115 - val_loss: 0.8590 - val_accuracy: 0.6910 - lr: 1.1611e-07
#
# Epoch 88: LearningRateScheduler setting learning rate to 1.0449567633177854e-07.
# Epoch 88/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8051 - accuracy: 0.7079 - val_loss: 0.8596 - val_accuracy: 0.6910 - lr: 1.0450e-07
#
# Epoch 89: LearningRateScheduler setting learning rate to 9.404610869860068e-08.
# Epoch 89/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7927 - accuracy: 0.7139 - val_loss: 0.8589 - val_accuracy: 0.6926 - lr: 9.4046e-08
#
# Epoch 90: LearningRateScheduler setting learning rate to 8.464149782874062e-08.
# Epoch 90/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.8073 - accuracy: 0.7131 - val_loss: 0.8601 - val_accuracy: 0.6910 - lr: 8.4641e-08
#
# Epoch 91: LearningRateScheduler setting learning rate to 7.617734804586657e-08.
# Epoch 91/1000
# 158/158 [==============================] - 2s 11ms/step - loss: 0.8037 - accuracy: 0.7131 - val_loss: 0.8602 - val_accuracy: 0.6910 - lr: 7.6177e-08
#
# Epoch 92: LearningRateScheduler setting learning rate to 6.85596132412799e-08.
# Epoch 92/1000
# 158/158 [==============================] - 2s 12ms/step - loss: 0.8170 - accuracy: 0.7103 - val_loss: 0.8599 - val_accuracy: 0.6910 - lr: 6.8560e-08
#
# Epoch 93: LearningRateScheduler setting learning rate to 6.170365191715192e-08.
# Epoch 93/1000
# 158/158 [==============================] - 2s 11ms/step - loss: 0.8149 - accuracy: 0.7044 - val_loss: 0.8587 - val_accuracy: 0.6910 - lr: 6.1704e-08
#
# Epoch 94: LearningRateScheduler setting learning rate to 5.5533286725436726e-08.
# Epoch 94/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7971 - accuracy: 0.7131 - val_loss: 0.8592 - val_accuracy: 0.6910 - lr: 5.5533e-08
#
# Epoch 95: LearningRateScheduler setting learning rate to 4.997995805289306e-08.
# Epoch 95/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8001 - accuracy: 0.7071 - val_loss: 0.8595 - val_accuracy: 0.6910 - lr: 4.9980e-08
#
# Epoch 96: LearningRateScheduler setting learning rate to 4.498196224760375e-08.
# Epoch 96/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8058 - accuracy: 0.7171 - val_loss: 0.8584 - val_accuracy: 0.6926 - lr: 4.4982e-08
#
# Epoch 97: LearningRateScheduler setting learning rate to 4.048376602284338e-08.
# Epoch 97/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8070 - accuracy: 0.7052 - val_loss: 0.8596 - val_accuracy: 0.6910 - lr: 4.0484e-08
#
# Epoch 98: LearningRateScheduler setting learning rate to 3.643538942055904e-08.
# Epoch 98/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7924 - accuracy: 0.7194 - val_loss: 0.8592 - val_accuracy: 0.6926 - lr: 3.6435e-08
#
# Epoch 99: LearningRateScheduler setting learning rate to 3.279185047850314e-08.
# Epoch 99/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7861 - accuracy: 0.7254 - val_loss: 0.8589 - val_accuracy: 0.6941 - lr: 3.2792e-08
#
# Epoch 100: LearningRateScheduler setting learning rate to 2.9512665430652826e-08.
# Epoch 100/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7972 - accuracy: 0.7032 - val_loss: 0.8586 - val_accuracy: 0.6926 - lr: 2.9513e-08
#
# Epoch 101: LearningRateScheduler setting learning rate to 2.6561398887587545e-08.
# Epoch 101/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8167 - accuracy: 0.7004 - val_loss: 0.8586 - val_accuracy: 0.6926 - lr: 2.6561e-08
#
# Epoch 102: LearningRateScheduler setting learning rate to 2.390525899882879e-08.
# Epoch 102/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7735 - accuracy: 0.7317 - val_loss: 0.8584 - val_accuracy: 0.6926 - lr: 2.3905e-08
#
# Epoch 103: LearningRateScheduler setting learning rate to 2.151473309894591e-08.
# Epoch 103/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7940 - accuracy: 0.7103 - val_loss: 0.8596 - val_accuracy: 0.6894 - lr: 2.1515e-08
#
# Epoch 104: LearningRateScheduler setting learning rate to 1.9363259789051318e-08.
# Epoch 104/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8031 - accuracy: 0.7107 - val_loss: 0.8595 - val_accuracy: 0.6894 - lr: 1.9363e-08
#
# Epoch 105: LearningRateScheduler setting learning rate to 1.7426933810146187e-08.
# Epoch 105/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8145 - accuracy: 0.7060 - val_loss: 0.8590 - val_accuracy: 0.6910 - lr: 1.7427e-08
#
# Epoch 106: LearningRateScheduler setting learning rate to 1.568424042913157e-08.
# Epoch 106/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8071 - accuracy: 0.7091 - val_loss: 0.8589 - val_accuracy: 0.6926 - lr: 1.5684e-08
#
# Epoch 107: LearningRateScheduler setting learning rate to 1.4115816386218413e-08.
# Epoch 107/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7807 - accuracy: 0.7298 - val_loss: 0.8591 - val_accuracy: 0.6926 - lr: 1.4116e-08
#
# Epoch 108: LearningRateScheduler setting learning rate to 1.2704234747596572e-08.
# Epoch 108/1000
# 158/158 [==============================] - 1s 8ms/step - loss: 0.7975 - accuracy: 0.7103 - val_loss: 0.8596 - val_accuracy: 0.6926 - lr: 1.2704e-08
#
# Epoch 109: LearningRateScheduler setting learning rate to 1.1433811272836917e-08.
# Epoch 109/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8014 - accuracy: 0.7190 - val_loss: 0.8590 - val_accuracy: 0.6926 - lr: 1.1434e-08
#
# Epoch 110: LearningRateScheduler setting learning rate to 1.0290430145553225e-08.
# Epoch 110/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7909 - accuracy: 0.7151 - val_loss: 0.8589 - val_accuracy: 0.6926 - lr: 1.0290e-08
#
# Epoch 111: LearningRateScheduler setting learning rate to 9.2613871309979e-09.
# Epoch 111/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8007 - accuracy: 0.7131 - val_loss: 0.8597 - val_accuracy: 0.6910 - lr: 9.2614e-09
#
# Epoch 112: LearningRateScheduler setting learning rate to 8.335248417898112e-09.
# Epoch 112/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7816 - accuracy: 0.7175 - val_loss: 0.8585 - val_accuracy: 0.6926 - lr: 8.3352e-09
#
# Epoch 113: LearningRateScheduler setting learning rate to 7.5017235761083e-09.
# Epoch 113/1000
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8165 - accuracy: 0.7032 - val_loss: 0.8596 - val_accuracy: 0.6894 - lr: 7.5017e-09
#
# Epoch 114: LearningRateScheduler setting learning rate to 6.751551218497471e-09.
# Epoch 114/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.8097 - accuracy: 0.7175 - val_loss: 0.8590 - val_accuracy: 0.6926 - lr: 6.7516e-09
#
# Epoch 115: LearningRateScheduler setting learning rate to 6.076396096647724e-09.
# Epoch 115/1000
# 158/158 [==============================] - 1s 9ms/step - loss: 0.7909 - accuracy: 0.7131 - val_loss: 0.8594 - val_accuracy: 0.6910 - lr: 6.0764e-09

# %%
# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(X_test_reshaped, y_test_encoded)
print(f"CNN Test Loss: {cnn_loss}, Test Accuracy: {cnn_accuracy}")
# Save the CNN model
cnn_model.save('ser_cnn_model.h5')
# Save end to end model (with feature extraction, scaler, and CNN)
import joblib
end_to_end_model = {
    'feature_extractor': smile,
    'scaler': scaler,
    'cnn_model': cnn_model,
    'label_encoder': le
}
joblib.dump(end_to_end_model, 'ser_end_to_end_model.joblib')
# Out:
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7838 - accuracy: 0.7269
# CNN Test Loss: 0.7838073372840881, Test Accuracy: 0.7268689870834351
# ['ser_end_to_end_model.joblib']

# %%
X1_test_scaled = scaler.transform(X1)
X1_test_reshaped = X1_test_scaled.reshape(-1, X1.shape[1], 1)
y1 = le.transform(y1)  # Encode labels for EMO-DB
X2_test_scaled = scaler.transform(X2)
X2_test_reshaped = X2_test_scaled.reshape(-1, X2.shape[1], 1)
y2 = le.transform(y2)  # Encode labels for RAVDESS
X3_test_scaled = scaler.transform(X3)
X3_test_reshaped = X3_test_scaled.reshape(-1, X3.shape[1], 1)
y3 = le.transform(y3)  # Encode labels for TESS
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/utils/_encode.py:225, in _encode(values, uniques, check_unknown)
#     224 try:
# --> 225     return _map_to_integer(values, uniques)
#     226 except KeyError as e:
#
# File ~/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/utils/_encode.py:165, in _map_to_integer(values, uniques)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/utils/_encode.py:165, in <listcomp>(.0)
#     164 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 165 return np.array([table[v] for v in values])
#
# File ~/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/utils/_encode.py:159, in _nandict.__missing__(self, key)
#     158     return self.nan_value
# --> 159 raise KeyError(key)
#
# KeyError: 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 3
#       1 X1_test_scaled = scaler.transform(X1)
#       2 X1_test_reshaped = X1_test_scaled.reshape(-1, X1.shape[1], 1)
# ----> 3 y1 = le.transform(y1)  # Encode labels for EMO-DB
#       4 X2_test_scaled = scaler.transform(X2)
#       5 X2_test_reshaped = X2_test_scaled.reshape(-1, X2.shape[1], 1)
#
# File ~/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/preprocessing/_label.py:137, in LabelEncoder.transform(self, y)
#     134 if _num_samples(y) == 0:
#     135     return np.array([])
# --> 137 return _encode(y, uniques=self.classes_)
#
# File ~/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/utils/_encode.py:227, in _encode(values, uniques, check_unknown)
#     225         return _map_to_integer(values, uniques)
#     226     except KeyError as e:
# --> 227         raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     228 else:
#     229     if check_unknown:
#
# ValueError: y contains previously unseen labels: 3

# %%
# Evaluate the CNN model on EMO-DB dataset
cnn_emodb_loss, cnn_emodb_accuracy = cnn_model.evaluate(feats_emodb.values.reshape(feats_emodb.shape[0], feats_emodb.shape[1], 1), y1)
print(f"CNN EMO-DB Test Loss: {cnn_emodb_loss}, Test Accuracy: {cnn_emodb_accuracy}")
# Evaluate the CNN model on RAVDESS dataset
cnn_ravdess_loss, cnn_ravdess_accuracy = cnn_model.evaluate(feats_ravdess.values.reshape(feats_ravdess.shape[0], feats_ravdess.shape[1], 1), y2)
print(f"CNN RAVDESS Test Loss: {cnn_ravdess_loss}, Test Accuracy: {cnn_ravdess_accuracy}")
# Evaluate the CNN model on TESS dataset
cnn_tess_loss, cnn_tess_accuracy = cnn_model.evaluate(feats_tess.values.reshape(feats_tess.shape[0], feats_tess.shape[1], 1), y3)
print(f"CNN TESS Test Loss: {cnn_tess_loss}, Test Accuracy: {cnn_tess_accuracy}")
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 141.8723 - accuracy: 0.1259
# CNN EMO-DB Test Loss: 141.87234497070312, Test Accuracy: 0.1259259283542633
# 11/11 [==============================] - 0s 3ms/step - loss: 135.6223 - accuracy: 0.1580
# CNN RAVDESS Test Loss: 135.62225341796875, Test Accuracy: 0.15804597735404968
# 28/28 [==============================] - 0s 3ms/step - loss: 159.7747 - accuracy: 0.1118
# CNN TESS Test Loss: 159.77474975585938, Test Accuracy: 0.11175115406513214

# %% [markdown]
# CNN + LSTM

# %% [markdown]
# - Short-term GeMAPS (LLDs only)
# - Fixed-length padding/truncation
# - CNN input-ready formatting
# - Feature scaling (per-feature)

# %%
from tensorflow.keras.layers import LSTM, TimeDistributed, BatchNormalization

def create_cnn_lstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(LSTM(64, return_sequences=False))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer=tf.keras.optimizers.Adam(0.0003), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Train on X_train, y_train
cnn_model = create_cnn_lstm_model((X_train.shape[1], 1), len(df['label'].unique()))
# add early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
# add a callback to save the best model
checkpoint = tf.keras.callbacks.ModelCheckpoint('ser_cnn_model.h5', monitor='val_loss', save_best_only=True, mode='min')
# add the checkpoint to the callbacks
callbacks = [early_stopping, checkpoint]
# learning rate scheduler
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-3 * 0.9 ** epoch, verbose=1)
callbacks.append(lr_scheduler)
# define learning rate as constant
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_reshaped = X_train_scaled.reshape(-1, X_train.shape[1], 1)
X_test_reshaped = X_test_scaled.reshape(-1, X_test.shape[1], 1)
# train the CNN model
cnn_model.fit(X_train_reshaped, y_train_encoded, epochs=1000, batch_size=16, validation_split=0.2, callbacks=callbacks)
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/1000
# 158/158 [==============================] - 9s 31ms/step - loss: 1.7635 - accuracy: 0.2948 - val_loss: 2.0425 - val_accuracy: 0.1854 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0009000000000000001.
# Epoch 2/1000
#   5/158 [..............................] - ETA: 4s - loss: 1.5971 - accuracy: 0.3250
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 158/158 [==============================] - 4s 27ms/step - loss: 1.5096 - accuracy: 0.4119 - val_loss: 1.7963 - val_accuracy: 0.2552 - lr: 9.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0008100000000000001.
# Epoch 3/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 1.3791 - accuracy: 0.4639 - val_loss: 1.3433 - val_accuracy: 0.4548 - lr: 8.1000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0007290000000000002.
# Epoch 4/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 1.3078 - accuracy: 0.4968 - val_loss: 1.2201 - val_accuracy: 0.5388 - lr: 7.2900e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0006561000000000001.
# Epoch 5/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 1.2770 - accuracy: 0.5143 - val_loss: 1.1496 - val_accuracy: 0.5468 - lr: 6.5610e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.00059049.
# Epoch 6/1000
# 158/158 [==============================] - 5s 29ms/step - loss:
1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7745 - accuracy: 0.7107 - val_loss: 0.8537 - val_accuracy: 0.6878 - lr: 7.8552e-06
#
# Epoch 48: LearningRateScheduler setting learning rate to 7.069650490151056e-06.
# Epoch 48/1000
# 158/158 [==============================] - 4s 28ms/step - loss: 0.7470 - accuracy: 0.7183 - val_loss: 0.8550 - val_accuracy: 0.6878 - lr: 7.0697e-06
#
# Epoch 49: LearningRateScheduler setting learning rate to 6.36268544113595e-06.
# Epoch 49/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7601 - accuracy: 0.7087 - val_loss: 0.8504 - val_accuracy: 0.6862 - lr: 6.3627e-06
#
# Epoch 50: LearningRateScheduler setting learning rate to 5.726416897022355e-06.
# Epoch 50/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7786 - accuracy: 0.7127 - val_loss: 0.8501 - val_accuracy: 0.6878 - lr: 5.7264e-06
#
# Epoch 51: LearningRateScheduler setting learning rate to 5.15377520732012e-06.
# Epoch 51/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7608 - accuracy: 0.7111 - val_loss: 0.8523 - val_accuracy: 0.6894 - lr: 5.1538e-06
#
# Epoch 52: LearningRateScheduler setting learning rate to 4.638397686588108e-06.
# Epoch 52/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7574 - accuracy: 0.7123 - val_loss: 0.8533 - val_accuracy: 0.6894 - lr: 4.6384e-06
#
# Epoch 53: LearningRateScheduler setting learning rate to 4.174557917929297e-06.
# Epoch 53/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7531 - accuracy: 0.7234 - val_loss: 0.8521 - val_accuracy: 0.6862 - lr: 4.1746e-06
#
# Epoch 54: LearningRateScheduler setting learning rate to 3.7571021261363675e-06.
# Epoch 54/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7416 - accuracy: 0.7202 - val_loss: 0.8521 - val_accuracy: 0.6846 - lr: 3.7571e-06
#
# Epoch 55: LearningRateScheduler setting learning rate to 3.381391913522731e-06.
# Epoch 55/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7503 - accuracy: 0.7198 - val_loss: 0.8506 - val_accuracy: 0.6862 - lr: 3.3814e-06
#
# Epoch 56: LearningRateScheduler setting learning rate to 3.0432527221704577e-06.
# Epoch 56/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7415 - accuracy: 0.7119 - val_loss: 0.8512 - val_accuracy: 0.6846 - lr: 3.0433e-06
#
# Epoch 57: LearningRateScheduler setting learning rate to 2.7389274499534123e-06.
# Epoch 57/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7566 - accuracy: 0.7246 - val_loss: 0.8534 - val_accuracy: 0.6846 - lr: 2.7389e-06
#
# Epoch 58: LearningRateScheduler setting learning rate to 2.465034704958071e-06.
# Epoch 58/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7502 - accuracy: 0.7143 - val_loss: 0.8518 - val_accuracy: 0.6878 - lr: 2.4650e-06
#
# Epoch 59: LearningRateScheduler setting learning rate to 2.218531234462264e-06.
# Epoch 59/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7586 - accuracy: 0.7095 - val_loss: 0.8528 - val_accuracy: 0.6862 - lr: 2.2185e-06
#
# Epoch 60: LearningRateScheduler setting learning rate to 1.9966781110160375e-06.
# Epoch 60/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7515 - accuracy: 0.7270 - val_loss: 0.8533 - val_accuracy: 0.6846 - lr: 1.9967e-06
#
# Epoch 61: LearningRateScheduler setting learning rate to 1.797010299914434e-06.
# Epoch 61/1000
# 158/158 [==============================] - 5s 29ms/step - loss: 0.7567 - accuracy: 0.7242 - val_loss: 0.8536 - val_accuracy: 0.6830 - lr: 1.7970e-06
#
# Epoch 62: LearningRateScheduler setting learning rate to 1.6173092699229906e-06.
# Epoch 62/1000
# 158/158 [==============================] - 5s 29ms/step - loss: 0.7514 - accuracy: 0.7198 - val_loss: 0.8540 - val_accuracy: 0.6830 - lr: 1.6173e-06
#
# Epoch 63: LearningRateScheduler setting learning rate to 1.4555783429306915e-06.
# Epoch 63/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7498 - accuracy: 0.7159 - val_loss: 0.8531 - val_accuracy: 0.6878 - lr: 1.4556e-06
#
# Epoch 64: LearningRateScheduler setting learning rate to 1.3100205086376223e-06.
# Epoch 64/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7516 - accuracy: 0.7163 - val_loss: 0.8537 - val_accuracy: 0.6846 - lr: 1.3100e-06
#
# Epoch 65: LearningRateScheduler setting learning rate to 1.1790184577738603e-06.
# Epoch 65/1000
# 158/158 [==============================] - 5s 30ms/step - loss: 0.7614 - accuracy: 0.7099 - val_loss: 0.8516 - val_accuracy: 0.6878 - lr: 1.1790e-06
#
# Epoch 66: LearningRateScheduler setting learning rate to 1.061116611996474e-06.
# Epoch 66/1000
# 158/158 [==============================] - 5s 29ms/step - loss: 0.7489 - accuracy: 0.7190 - val_loss: 0.8514 - val_accuracy: 0.6862 - lr: 1.0611e-06
#
# Epoch 67: LearningRateScheduler setting learning rate to 9.550049507968267e-07.
# Epoch 67/1000
# 158/158 [==============================] - 5s 31ms/step - loss: 0.7376 - accuracy: 0.7238 - val_loss: 0.8522 - val_accuracy: 0.6878 - lr: 9.5500e-07
#
# Epoch 68: LearningRateScheduler setting learning rate to 8.595044557171441e-07.
# Epoch 68/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7467 - accuracy: 0.7234 - val_loss: 0.8517 - val_accuracy: 0.6846 - lr: 8.5950e-07
#
# Epoch 69: LearningRateScheduler setting learning rate to 7.735540101454298e-07.
# Epoch 69/1000
# 158/158 [==============================] - 5s 30ms/step - loss: 0.7472 - accuracy: 0.7214 - val_loss: 0.8515 - val_accuracy: 0.6878 - lr: 7.7355e-07
#
# Epoch 70: LearningRateScheduler setting learning rate to 6.961986091308867e-07.
# Epoch 70/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7511 - accuracy: 0.7183 - val_loss: 0.8523 - val_accuracy: 0.6894 - lr: 6.9620e-07
#
# Epoch 71: LearningRateScheduler setting learning rate to 6.265787482177981e-07.
# Epoch 71/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7385 - accuracy: 0.7270 - val_loss: 0.8523 - val_accuracy: 0.6878 - lr: 6.2658e-07
#
# Epoch 72: LearningRateScheduler setting learning rate to 5.639208733960184e-07.
# Epoch 72/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7596 - accuracy: 0.7155 - val_loss: 0.8533 - val_accuracy: 0.6878 - lr: 5.6392e-07
#
# Epoch 73: LearningRateScheduler setting learning rate to 5.075287860564166e-07.
# Epoch 73/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7407 - accuracy: 0.7179 - val_loss: 0.8521 - val_accuracy: 0.6862 - lr: 5.0753e-07
#
# Epoch 74: LearningRateScheduler setting learning rate to 4.5677590745077486e-07.
# Epoch 74/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7420 - accuracy: 0.7262 - val_loss: 0.8516 - val_accuracy: 0.6878 - lr: 4.5678e-07
#
# Epoch 75: LearningRateScheduler setting learning rate to 4.110983167056974e-07.
# Epoch 75/1000
# 158/158 [==============================] - 4s 28ms/step - loss: 0.7691 - accuracy: 0.7131 - val_loss: 0.8511 - val_accuracy: 0.6846 - lr: 4.1110e-07
#
# Epoch 76: LearningRateScheduler setting learning rate to 3.699884850351277e-07.
# Epoch 76/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7437 - accuracy: 0.7242 - val_loss: 0.8508 - val_accuracy: 0.6894 - lr: 3.6999e-07
#
# Epoch 77: LearningRateScheduler setting learning rate to 3.329896365316149e-07.
# Epoch 77/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7474 - accuracy: 0.7210 - val_loss: 0.8511 - val_accuracy: 0.6894 - lr: 3.3299e-07
#
# Epoch 78: LearningRateScheduler setting learning rate to 2.996906728784534e-07.
# Epoch 78/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7362 - accuracy: 0.7139 - val_loss: 0.8529 - val_accuracy: 0.6878 - lr: 2.9969e-07
#
# Epoch 79: LearningRateScheduler setting learning rate to 2.6972160559060813e-07.
# Epoch 79/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7524 - accuracy: 0.7099 - val_loss: 0.8521 - val_accuracy: 0.6878 - lr: 2.6972e-07
#
# Epoch 80: LearningRateScheduler setting learning rate to 2.427494450315473e-07.
# Epoch 80/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7454 - accuracy: 0.7190 - val_loss: 0.8531 - val_accuracy: 0.6878 - lr: 2.4275e-07
#
# Epoch 81: LearningRateScheduler setting learning rate to 2.1847450052839256e-07.
# Epoch 81/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7370 - accuracy: 0.7298 - val_loss: 0.8534 - val_accuracy: 0.6894 - lr: 2.1847e-07
#
# Epoch 82: LearningRateScheduler setting learning rate to 1.966270504755533e-07.
# Epoch 82/1000
# 158/158 [==============================] - 4s 24ms/step - loss: 0.7460 - accuracy: 0.7163 - val_loss: 0.8521 - val_accuracy: 0.6878 - lr: 1.9663e-07
#
# Epoch 83: LearningRateScheduler setting learning rate to 1.7696434542799797e-07.
# Epoch 83/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7358 - accuracy: 0.7230 - val_loss: 0.8494 - val_accuracy: 0.6910 - lr: 1.7696e-07
#
# Epoch 84: LearningRateScheduler setting learning rate to 1.5926791088519817e-07.
# Epoch 84/1000
# 158/158 [==============================] - 4s 24ms/step - loss: 0.7512 - accuracy: 0.7159 - val_loss: 0.8515 - val_accuracy: 0.6878 - lr: 1.5927e-07
#
# Epoch 85: LearningRateScheduler setting learning rate to 1.4334111979667837e-07.
# Epoch 85/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7595 - accuracy: 0.7071 - val_loss: 0.8523 - val_accuracy: 0.6862 - lr: 1.4334e-07
#
# Epoch 86: LearningRateScheduler setting learning rate to 1.2900700781701054e-07.
# Epoch 86/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7586 - accuracy: 0.7151 - val_loss: 0.8517 - val_accuracy: 0.6878 - lr: 1.2901e-07
#
# Epoch 87: LearningRateScheduler setting learning rate to 1.1610630703530949e-07.
# Epoch 87/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7570 - accuracy: 0.7123 - val_loss: 0.8508 - val_accuracy: 0.6910 - lr: 1.1611e-07
#
# Epoch 88: LearningRateScheduler setting learning rate to 1.0449567633177854e-07.
# Epoch 88/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7607 - accuracy: 0.7111 - val_loss: 0.8513 - val_accuracy: 0.6878 - lr: 1.0450e-07
#
# Epoch 89: LearningRateScheduler setting learning rate to 9.404610869860068e-08.
# Epoch 89/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7657 - accuracy: 0.7151 - val_loss: 0.8510 - val_accuracy: 0.6894 - lr: 9.4046e-08
#
# Epoch 90: LearningRateScheduler setting learning rate to 8.464149782874062e-08.
# Epoch 90/1000
# 158/158 [==============================] - 4s 28ms/step - loss: 0.7506 - accuracy: 0.7266 - val_loss: 0.8535 - val_accuracy: 0.6830 - lr: 8.4641e-08
#
# Epoch 91: LearningRateScheduler setting learning rate to 7.617734804586657e-08.
# Epoch 91/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7532 - accuracy: 0.7163 - val_loss: 0.8524 - val_accuracy: 0.6878 - lr: 7.6177e-08
#
# Epoch 92: LearningRateScheduler setting learning rate to 6.85596132412799e-08.
# Epoch 92/1000
# 158/158 [==============================] - 5s 29ms/step - loss: 0.7508 - accuracy: 0.7175 - val_loss: 0.8495 - val_accuracy: 0.6894 - lr: 6.8560e-08
#
# Epoch 93: LearningRateScheduler setting learning rate to 6.170365191715192e-08.
# Epoch 93/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7549 - accuracy: 0.7119 - val_loss: 0.8492 - val_accuracy: 0.6862 - lr: 6.1704e-08
#
# Epoch 94: LearningRateScheduler setting learning rate to 5.5533286725436726e-08.
# Epoch 94/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7344 - accuracy: 0.7313 - val_loss: 0.8527 - val_accuracy: 0.6862 - lr: 5.5533e-08
#
# Epoch 95: LearningRateScheduler setting learning rate to 4.997995805289306e-08.
# Epoch 95/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7437 - accuracy: 0.7286 - val_loss: 0.8514 - val_accuracy: 0.6878 - lr: 4.9980e-08
#
# Epoch 96: LearningRateScheduler setting learning rate to 4.498196224760375e-08.
# Epoch 96/1000
# 158/158 [==============================] - 4s 28ms/step - loss: 0.7444 - accuracy: 0.7246 - val_loss: 0.8521 - val_accuracy: 0.6894 - lr: 4.4982e-08
#
# Epoch 97: LearningRateScheduler setting learning rate to 4.048376602284338e-08.
# Epoch 97/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7506 - accuracy: 0.7139 - val_loss: 0.8525 - val_accuracy: 0.6862 - lr: 4.0484e-08
#
# Epoch 98: LearningRateScheduler setting learning rate to 3.643538942055904e-08.
# Epoch 98/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7513 - accuracy: 0.7183 - val_loss: 0.8540 - val_accuracy: 0.6830 - lr: 3.6435e-08
#
# Epoch 99: LearningRateScheduler setting learning rate to 3.279185047850314e-08.
# Epoch 99/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7498 - accuracy: 0.7202 - val_loss: 0.8516 - val_accuracy: 0.6846 - lr: 3.2792e-08
#
# Epoch 100: LearningRateScheduler setting learning rate to 2.9512665430652826e-08.
# Epoch 100/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7509 - accuracy: 0.7254 - val_loss: 0.8528 - val_accuracy: 0.6846 - lr: 2.9513e-08
#
# Epoch 101: LearningRateScheduler setting learning rate to 2.6561398887587545e-08.
# Epoch 101/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7410 - accuracy: 0.7238 - val_loss: 0.8498 - val_accuracy: 0.6894 - lr: 2.6561e-08
#
# Epoch 102: LearningRateScheduler setting learning rate to 2.390525899882879e-08.
# Epoch 102/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7626 - accuracy: 0.7147 - val_loss: 0.8512 - val_accuracy: 0.6862 - lr: 2.3905e-08
#
# Epoch 103: LearningRateScheduler setting learning rate to 2.151473309894591e-08.
# Epoch 103/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7551 - accuracy: 0.7143 - val_loss: 0.8516 - val_accuracy: 0.6894 - lr: 2.1515e-08
#
# Epoch 104: LearningRateScheduler setting learning rate to 1.9363259789051318e-08.
# Epoch 104/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7483 - accuracy: 0.7179 - val_loss: 0.8512 - val_accuracy: 0.6894 - lr: 1.9363e-08
#
# Epoch 105: LearningRateScheduler setting learning rate to 1.7426933810146187e-08.
# Epoch 105/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7589 - accuracy: 0.7147 - val_loss: 0.8525 - val_accuracy: 0.6878 - lr: 1.7427e-08
#
# Epoch 106: LearningRateScheduler setting learning rate to 1.568424042913157e-08.
# Epoch 106/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7346 - accuracy: 0.7222 - val_loss: 0.8526 - val_accuracy: 0.6878 - lr: 1.5684e-08
#
# Epoch 107: LearningRateScheduler setting learning rate to 1.4115816386218413e-08.
# Epoch 107/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7376 - accuracy: 0.7206 - val_loss: 0.8526 - val_accuracy: 0.6878 - lr: 1.4116e-08
#
# Epoch 108: LearningRateScheduler setting learning rate to 1.2704234747596572e-08.
# Epoch 108/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7531 - accuracy: 0.7155 - val_loss: 0.8544 - val_accuracy: 0.6815 - lr: 1.2704e-08
#
# Epoch 109: LearningRateScheduler setting learning rate to 1.1433811272836917e-08.
# Epoch 109/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7328 - accuracy: 0.7325 - val_loss: 0.8539 - val_accuracy: 0.6815 - lr: 1.1434e-08
#
# Epoch 110: LearningRateScheduler setting learning rate to 1.0290430145553225e-08.
# Epoch 110/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7538 - accuracy: 0.7147 - val_loss: 0.8526 - val_accuracy: 0.6878 - lr: 1.0290e-08
#
# Epoch 111: LearningRateScheduler setting learning rate to 9.2613871309979e-09.
# Epoch 111/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7494 - accuracy: 0.7262 - val_loss: 0.8528 - val_accuracy: 0.6910 - lr: 9.2614e-09
#
# Epoch 112: LearningRateScheduler setting learning rate to 8.335248417898112e-09.
# Epoch 112/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7495 - accuracy: 0.7222 - val_loss: 0.8519 - val_accuracy: 0.6878 - lr: 8.3352e-09
#
# Epoch 113: LearningRateScheduler setting learning rate to 7.5017235761083e-09.
# Epoch 113/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7319 - accuracy: 0.7230 - val_loss: 0.8525 - val_accuracy: 0.6846 - lr: 7.5017e-09
#
# Epoch 114: LearningRateScheduler setting learning rate to 6.751551218497471e-09.
# Epoch 114/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7424 - accuracy: 0.7290 - val_loss: 0.8494 - val_accuracy: 0.6878 - lr: 6.7516e-09
#
# Epoch 115: LearningRateScheduler setting learning rate to 6.076396096647724e-09.
# Epoch 115/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7501 - accuracy: 0.7226 - val_loss: 0.8486 - val_accuracy: 0.6878 - lr: 6.0764e-09
#
# Epoch 116: LearningRateScheduler setting learning rate to 5.4687564869829525e-09.
# Epoch 116/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7569 - accuracy: 0.7198 - val_loss: 0.8506 - val_accuracy: 0.6862 - lr: 5.4688e-09
#
# Epoch 117: LearningRateScheduler setting learning rate to 4.921880838284657e-09.
# Epoch 117/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7486 - accuracy: 0.7175 - val_loss: 0.8532 - val_accuracy: 0.6846 - lr: 4.9219e-09
#
# Epoch 118: LearningRateScheduler setting learning rate to 4.429692754456192e-09.
# Epoch 118/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7364 - accuracy: 0.7278 - val_loss: 0.8528 - val_accuracy: 0.6846 - lr: 4.4297e-09
#
# Epoch 119: LearningRateScheduler setting learning rate to 3.986723479010572e-09.
# Epoch 119/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7351 - accuracy: 0.7194 - val_loss: 0.8516 - val_accuracy: 0.6862 - lr: 3.9867e-09
#
# Epoch 120: LearningRateScheduler setting learning rate to 3.588051131109515e-09.
# Epoch 120/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7349 - accuracy: 0.7317 - val_loss: 0.8525 - val_accuracy: 0.6894 - lr: 3.5881e-09
#
# Epoch 121: LearningRateScheduler setting learning rate to 3.2292460179985636e-09.
# Epoch 121/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7604 - accuracy: 0.7119 - val_loss: 0.8525 - val_accuracy: 0.6862 - lr: 3.2292e-09
#
# Epoch 122: LearningRateScheduler setting learning rate to 2.9063214161987073e-09.
# Epoch 122/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7555 - accuracy: 0.7151 - val_loss: 0.8508 - val_accuracy: 0.6878 - lr: 2.9063e-09
#
# Epoch 123: LearningRateScheduler setting learning rate to 2.6156892745788367e-09.
# Epoch 123/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7532 - accuracy: 0.7127 - val_loss: 0.8488 - val_accuracy: 0.6878 - lr: 2.6157e-09
#
# Epoch 124: LearningRateScheduler setting learning rate to 2.354120347120953e-09.
# Epoch 124/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7448 - accuracy: 0.7179 - val_loss: 0.8520 - val_accuracy: 0.6878 - lr: 2.3541e-09
#
# Epoch 125: LearningRateScheduler setting learning rate to 2.118708312408858e-09.
# Epoch 125/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7410 - accuracy: 0.7222 - val_loss: 0.8531 - val_accuracy: 0.6894 - lr: 2.1187e-09
#
# Epoch 126: LearningRateScheduler setting learning rate to 1.906837481167972e-09.
# Epoch 126/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7469 - accuracy: 0.7218 - val_loss: 0.8520 - val_accuracy: 0.6878 - lr: 1.9068e-09
#
# Epoch 127: LearningRateScheduler setting learning rate to 1.716153733051175e-09.
# Epoch 127/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7532 - accuracy: 0.7151 - val_loss: 0.8515 - val_accuracy: 0.6878 - lr: 1.7162e-09
#
# Epoch 128: LearningRateScheduler setting learning rate to 1.5445383597460575e-09.
# Epoch 128/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7555 - accuracy: 0.7179 - val_loss: 0.8508 - val_accuracy: 0.6878 - lr: 1.5445e-09
#
# Epoch 129: LearningRateScheduler setting learning rate to 1.3900845237714517e-09.
# Epoch 129/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7502 - accuracy: 0.7190 - val_loss: 0.8509 - val_accuracy: 0.6878 - lr: 1.3901e-09
#
# Epoch 130: LearningRateScheduler setting learning rate to 1.2510760713943067e-09.
# Epoch 130/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7564 - accuracy: 0.7190 - val_loss: 0.8512 - val_accuracy: 0.6894 - lr: 1.2511e-09
#
# Epoch 131: LearningRateScheduler setting learning rate to 1.125968464254876e-09.
# Epoch 131/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7478 - accuracy: 0.7230 - val_loss: 0.8537 - val_accuracy: 0.6894 - lr: 1.1260e-09
#
# Epoch 132: LearningRateScheduler setting learning rate to 1.0133716178293883e-09.
# Epoch 132/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7286 - accuracy: 0.7230 - val_loss: 0.8508 - val_accuracy: 0.6862 - lr: 1.0134e-09
#
# Epoch 133: LearningRateScheduler setting learning rate to 9.120344560464495e-10.
# Epoch 133/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7577 - accuracy: 0.7139 - val_loss: 0.8492 - val_accuracy: 0.6862 - lr: 9.1203e-10
#
# Epoch 134: LearningRateScheduler setting learning rate to 8.208310104418046e-10.
# Epoch 134/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7469 - accuracy: 0.7147 - val_loss: 0.8500 - val_accuracy: 0.6846 - lr: 8.2083e-10
#
# Epoch 135: LearningRateScheduler setting learning rate to 7.387479093976243e-10.
# Epoch 135/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7645 - accuracy: 0.7171 - val_loss: 0.8521 - val_accuracy: 0.6878 - lr: 7.3875e-10
#
# Epoch 136: LearningRateScheduler setting learning rate to 6.648731184578618e-10.
# Epoch 136/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7521 - accuracy: 0.7167 - val_loss: 0.8525 - val_accuracy: 0.6910 - lr: 6.6487e-10
#
# Epoch 137: LearningRateScheduler setting learning rate to 5.983858066120756e-10.
# Epoch 137/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7464 - accuracy: 0.7123 - val_loss: 0.8511 - val_accuracy: 0.6862 - lr: 5.9839e-10
#
# Epoch 138: LearningRateScheduler setting learning rate to 5.385472259508681e-10.
# Epoch 138/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7542 - accuracy: 0.7187 - val_loss: 0.8507 - val_accuracy: 0.6846 - lr: 5.3855e-10
#
# Epoch 139: LearningRateScheduler setting learning rate to 4.846925033557813e-10.
# Epoch 139/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7576 - accuracy: 0.7167 - val_loss: 0.8534 - val_accuracy: 0.6862 - lr: 4.8469e-10
#
# Epoch 140: LearningRateScheduler setting learning rate to 4.362232530202031e-10.
# Epoch 140/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7445 - accuracy: 0.7226 - val_loss: 0.8523 - val_accuracy: 0.6878 - lr: 4.3622e-10
#
# Epoch 141: LearningRateScheduler setting learning rate to 3.9260092771818286e-10.
# Epoch 141/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7588 - accuracy: 0.7187 - val_loss: 0.8522 - val_accuracy: 0.6846 - lr: 3.9260e-10
#
# Epoch 142: LearningRateScheduler setting learning rate to 3.5334083494636456e-10.
# Epoch 142/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7633 - accuracy: 0.7139 - val_loss: 0.8523 - val_accuracy: 0.6862 - lr: 3.5334e-10
#
# Epoch 143: LearningRateScheduler setting learning rate to 3.180067514517281e-10.
# Epoch 143/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7487 - accuracy: 0.7171 - val_loss: 0.8517 - val_accuracy: 0.6878 - lr: 3.1801e-10
#
# Epoch 144: LearningRateScheduler setting learning rate to 2.8620607630655533e-10.
# Epoch 144/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7438 - accuracy: 0.7139 - val_loss: 0.8514 - val_accuracy: 0.6894 - lr: 2.8621e-10
#
# Epoch 145: LearningRateScheduler setting learning rate to 2.575854686758998e-10.
# Epoch 145/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7492 - accuracy: 0.7317 - val_loss: 0.8498 - val_accuracy: 0.6878 - lr: 2.5759e-10
#
# Epoch 146: LearningRateScheduler setting learning rate to 2.3182692180830982e-10.
# Epoch 146/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7471 - accuracy: 0.7159 - val_loss: 0.8506 - val_accuracy: 0.6878 - lr: 2.3183e-10
#
# Epoch 147: LearningRateScheduler setting learning rate to 2.0864422962747884e-10.
# Epoch 147/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7710 - accuracy: 0.7115 - val_loss: 0.8516 - val_accuracy: 0.6862 - lr: 2.0864e-10
#
# Epoch 148: LearningRateScheduler setting learning rate to 1.8777980666473098e-10.
# Epoch 148/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7540 - accuracy: 0.7171 - val_loss: 0.8521 - val_accuracy: 0.6878 - lr: 1.8778e-10
#
# Epoch 149: LearningRateScheduler setting learning rate to 1.6900182599825787e-10.
# Epoch 149/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7663 - accuracy: 0.7159 - val_loss: 0.8522 - val_accuracy: 0.6878 - lr: 1.6900e-10
#
# Epoch 150: LearningRateScheduler setting learning rate to 1.521016433984321e-10.
# Epoch 150/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7472 - accuracy: 0.7242 - val_loss: 0.8514 - val_accuracy: 0.6894 - lr: 1.5210e-10
#
# Epoch 151: LearningRateScheduler setting learning rate to 1.368914790585889e-10.
# Epoch 151/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7450 - accuracy: 0.7246 - val_loss: 0.8486 - val_accuracy: 0.6862 - lr: 1.3689e-10
#
# Epoch 152: LearningRateScheduler setting learning rate to 1.2320233115273e-10.
# Epoch 152/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7519 - accuracy: 0.7131 - val_loss: 0.8507 - val_accuracy: 0.6894 - lr: 1.2320e-10
#
# Epoch 153: LearningRateScheduler setting learning rate to 1.10882098037457e-10.
# Epoch 153/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7421 - accuracy: 0.7167 - val_loss: 0.8518 - val_accuracy: 0.6894 - lr: 1.1088e-10
#
# Epoch 154: LearningRateScheduler setting learning rate to 9.97938882337113e-11.
# Epoch 154/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7519 - accuracy: 0.7151 - val_loss: 0.8502 - val_accuracy: 0.6910 - lr: 9.9794e-11
#
# Epoch 155: LearningRateScheduler setting learning rate to 8.981449941034018e-11.
# Epoch 155/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7364 - accuracy: 0.7286 - val_loss: 0.8526 - val_accuracy: 0.6878 - lr: 8.9814e-11
#
# Epoch 156: LearningRateScheduler setting learning rate to 8.083304946930616e-11.
# Epoch 156/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7501 - accuracy: 0.7194 - val_loss: 0.8534 - val_accuracy: 0.6878 - lr: 8.0833e-11
#
# Epoch 157: LearningRateScheduler setting learning rate to 7.274974452237554e-11.
# Epoch 157/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7588 - accuracy: 0.7131 - val_loss: 0.8507 - val_accuracy: 0.6878 - lr: 7.2750e-11
#
# Epoch 158: LearningRateScheduler setting learning rate to 6.5474770070138e-11.
# Epoch 158/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7631 - accuracy: 0.7202 - val_loss: 0.8521 - val_accuracy: 0.6862 - lr: 6.5475e-11
#
# Epoch 159: LearningRateScheduler setting learning rate to 5.89272930631242e-11.
# Epoch 159/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7391 - accuracy: 0.7274 - val_loss: 0.8533 - val_accuracy: 0.6862 - lr: 5.8927e-11
#
# Epoch 160: LearningRateScheduler setting learning rate to 5.303456375681178e-11.
# Epoch 160/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7602 - accuracy: 0.7095 - val_loss: 0.8529 - val_accuracy: 0.6878 - lr: 5.3035e-11
#
# Epoch 161: LearningRateScheduler setting learning rate to 4.77311073811306e-11.
# Epoch 161/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7375 - accuracy: 0.7143 - val_loss: 0.8517 - val_accuracy: 0.6894 - lr: 4.7731e-11
#
# Epoch 162: LearningRateScheduler setting learning rate to 4.295799664301755e-11.
# Epoch 162/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7496 - accuracy: 0.7222 - val_loss: 0.8504 - val_accuracy: 0.6878 - lr: 4.2958e-11
#
# Epoch 163: LearningRateScheduler setting learning rate to 3.866219697871579e-11.
# Epoch 163/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7548 - accuracy: 0.7183 - val_loss: 0.8518 - val_accuracy: 0.6894 - lr: 3.8662e-11
#
# Epoch 164: LearningRateScheduler setting learning rate to 3.479597728084421e-11.
# Epoch 164/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7507 - accuracy: 0.7175 - val_loss: 0.8529 - val_accuracy: 0.6862 - lr: 3.4796e-11
#
# Epoch 165: LearningRateScheduler setting learning rate to 3.131637955275979e-11.
# Epoch 165/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7502 - accuracy: 0.7171 - val_loss: 0.8514 - val_accuracy: 0.6862 - lr: 3.1316e-11
#
# Epoch 166: LearningRateScheduler setting learning rate to 2.818474159748381e-11.
# Epoch 166/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7534 - accuracy: 0.7127 - val_loss: 0.8513 - val_accuracy: 0.6878 - lr: 2.8185e-11
#
# Epoch 167: LearningRateScheduler setting learning rate to 2.536626743773543e-11.
# Epoch 167/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7558 - accuracy: 0.7198 - val_loss: 0.8522 - val_accuracy: 0.6894 - lr: 2.5366e-11
#
# Epoch 168: LearningRateScheduler setting learning rate to 2.2829640693961888e-11.
# Epoch 168/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7544 - accuracy: 0.7234 - val_loss: 0.8507 - val_accuracy: 0.6862 - lr: 2.2830e-11
#
# Epoch 169: LearningRateScheduler setting learning rate to 2.05466766245657e-11.
# Epoch 169/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7374 - accuracy: 0.7290 - val_loss: 0.8508 - val_accuracy: 0.6894 - lr: 2.0547e-11
#
# Epoch 170: LearningRateScheduler setting learning rate to 1.849200896210913e-11.
# Epoch 170/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7309 - accuracy: 0.7282 - val_loss: 0.8503 - val_accuracy: 0.6894 - lr: 1.8492e-11
#
# Epoch 171: LearningRateScheduler setting learning rate to 1.6642808065898218e-11.
# Epoch 171/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7575 - accuracy: 0.7151 - val_loss: 0.8527 - val_accuracy: 0.6878 - lr: 1.6643e-11
#
# Epoch 172: LearningRateScheduler setting learning rate to 1.4978527259308397e-11.
# Epoch 172/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7564 - accuracy: 0.7202 - val_loss: 0.8510 - val_accuracy: 0.6862 - lr: 1.4979e-11
#
# Epoch 173: LearningRateScheduler setting learning rate to 1.3480674533377557e-11.
# Epoch 173/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7427 - accuracy: 0.7147 - val_loss: 0.8510 - val_accuracy: 0.6862 - lr: 1.3481e-11
#
# Epoch 174: LearningRateScheduler setting learning rate to 1.2132607080039803e-11.
# Epoch 174/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7487 - accuracy: 0.7310 - val_loss: 0.8515 - val_accuracy: 0.6862 - lr: 1.2133e-11
#
# Epoch 175: LearningRateScheduler setting learning rate to 1.0919346372035822e-11.
# Epoch 175/1000
# 158/158 [==============================] - 4s 28ms/step - loss: 0.7421 - accuracy: 0.7234 - val_loss: 0.8525 - val_accuracy: 0.6878 - lr: 1.0919e-11
#
# Epoch 176: LearningRateScheduler setting learning rate to 9.82741173483224e-12.
# Epoch 176/1000
# 158/158 [==============================] - 4s 28ms/step - loss: 0.7638 - accuracy: 0.7103 - val_loss: 0.8523 - val_accuracy: 0.6894 - lr: 9.8274e-12
#
# Epoch 177: LearningRateScheduler setting learning rate to 8.844670561349017e-12.
# Epoch 177/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7429 - accuracy: 0.7254 - val_loss: 0.8503 - val_accuracy: 0.6910 - lr: 8.8447e-12
#
# Epoch 178: LearningRateScheduler setting learning rate to 7.960203505214116e-12.
# Epoch 178/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7333 - accuracy: 0.7230 - val_loss: 0.8490 - val_accuracy: 0.6894 - lr: 7.9602e-12
#
# Epoch 179: LearningRateScheduler setting learning rate to 7.1641831546927035e-12.
# Epoch 179/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7341 - accuracy: 0.7222 - val_loss: 0.8519 - val_accuracy: 0.6878 - lr: 7.1642e-12
#
# Epoch 180: LearningRateScheduler setting learning rate to 6.4477648392234336e-12.
# Epoch 180/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7628 - accuracy: 0.7147 - val_loss: 0.8527 - val_accuracy: 0.6878 - lr: 6.4478e-12
#
# Epoch 181: LearningRateScheduler setting learning rate to 5.80298835530109e-12.
# Epoch 181/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7374 - accuracy: 0.7234 - val_loss: 0.8529 - val_accuracy: 0.6862 - lr: 5.8030e-12
#
# Epoch 182: LearningRateScheduler setting learning rate to 5.222689519770981e-12.
# Epoch 182/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7313 - accuracy: 0.7214 - val_loss: 0.8514 - val_accuracy: 0.6862 - lr: 5.2227e-12
#
# Epoch 183: LearningRateScheduler setting learning rate to 4.700420567793883e-12.
# Epoch 183/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7382 - accuracy: 0.7302 - val_loss: 0.8505 - val_accuracy: 0.6862 - lr: 4.7004e-12
#
# Epoch 184: LearningRateScheduler setting learning rate to 4.2303785110144954e-12.
# Epoch 184/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7490 - accuracy: 0.7139 - val_loss: 0.8515 - val_accuracy: 0.6878 - lr: 4.2304e-12
#
# Epoch 185: LearningRateScheduler setting learning rate to 3.807340659913046e-12.
# Epoch 185/1000
# 158/158 [==============================] - 4s 25ms/step - loss: 0.7637 - accuracy: 0.7083 - val_loss: 0.8500 - val_accuracy: 0.6878 - lr: 3.8073e-12
#
# Epoch 186: LearningRateScheduler setting learning rate to 3.426606593921741e-12.
# Epoch 186/1000
# 158/158 [==============================] - 4s 24ms/step - loss: 0.7534 - accuracy: 0.7198 - val_loss: 0.8506 - val_accuracy: 0.6878 - lr: 3.4266e-12
#
# Epoch 187: LearningRateScheduler setting learning rate to 3.083945934529567e-12.
# Epoch 187/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7540 - accuracy: 0.7159 - val_loss: 0.8517 - val_accuracy: 0.6878 - lr: 3.0839e-12
#
# Epoch 188: LearningRateScheduler setting learning rate to 2.7755513410766104e-12.
# Epoch 188/1000
# 158/158 [==============================] - 926s 6s/step - loss: 0.7431 - accuracy: 0.7198 - val_loss: 0.8526 - val_accuracy: 0.6894 - lr: 2.7756e-12
#
# Epoch 189: LearningRateScheduler setting learning rate to 2.4979962069689493e-12.
# Epoch 189/1000
# 158/158 [==============================] - 4s 28ms/step - loss: 0.7439 - accuracy: 0.7214 - val_loss: 0.8514 - val_accuracy: 0.6894 - lr: 2.4980e-12
#
# Epoch 190: LearningRateScheduler setting learning rate to 2.2481965862720545e-12.
# Epoch 190/1000
# 158/158 [==============================] - 4s 28ms/step - loss: 0.7362 - accuracy: 0.7258 - val_loss: 0.8503 - val_accuracy: 0.6878 - lr: 2.2482e-12
#
# Epoch 191: LearningRateScheduler setting learning rate to 2.023376927644849e-12.
# Epoch 191/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7532 - accuracy: 0.7187 - val_loss: 0.8498 - val_accuracy: 0.6878 - lr: 2.0234e-12
#
# Epoch 192: LearningRateScheduler setting learning rate to 1.8210392348803643e-12.
# Epoch 192/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7347 - accuracy: 0.7313 - val_loss: 0.8500 - val_accuracy: 0.6878 - lr: 1.8210e-12
#
# Epoch 193: LearningRateScheduler setting learning rate to 1.638935311392328e-12.
# Epoch 193/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7596 - accuracy: 0.7147 - val_loss: 0.8527 - val_accuracy: 0.6878 - lr: 1.6389e-12
#
# Epoch 194: LearningRateScheduler setting learning rate to 1.475041780253095e-12.
# Epoch 194/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7444 - accuracy: 0.7139 - val_loss: 0.8522 - val_accuracy: 0.6878 - lr: 1.4750e-12
#
# Epoch 195: LearningRateScheduler setting learning rate to 1.3275376022277856e-12.
# Epoch 195/1000
# 158/158 [==============================] - 5s 33ms/step - loss: 0.7524 - accuracy: 0.7187 - val_loss: 0.8517 - val_accuracy: 0.6862 - lr: 1.3275e-12
#
# Epoch 196: LearningRateScheduler setting learning rate to 1.194783842005007e-12.
# Epoch 196/1000
# 158/158 [==============================] - 5s 29ms/step - loss: 0.7413 - accuracy: 0.7242 - val_loss: 0.8535 - val_accuracy: 0.6830 - lr: 1.1948e-12
#
# Epoch 197: LearningRateScheduler setting learning rate to 1.0753054578045064e-12.
# Epoch 197/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7450 - accuracy: 0.7159 - val_loss: 0.8534 - val_accuracy: 0.6862 - lr: 1.0753e-12
#
# Epoch 198: LearningRateScheduler setting learning rate to 9.677749120240557e-13.
# Epoch 198/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7540 - accuracy: 0.7155 - val_loss: 0.8527 - val_accuracy: 0.6862 - lr: 9.6777e-13
#
# Epoch 199: LearningRateScheduler setting learning rate to 8.709974208216503e-13.
# Epoch 199/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7615 - accuracy: 0.7139 - val_loss: 0.8521 - val_accuracy: 0.6894 - lr: 8.7100e-13
#
# Epoch 200: LearningRateScheduler setting learning rate to 7.838976787394853e-13.
# Epoch 200/1000
# 158/158 [==============================] - 4s 26ms/step - loss: 0.7494 - accuracy: 0.7179 - val_loss: 0.8531 - val_accuracy: 0.6878 - lr: 7.8390e-13
#
# Epoch 201: LearningRateScheduler setting learning rate to 7.055079108655367e-13.
# Epoch 201/1000
# 158/158 [==============================] - 4s 27ms/step - loss: 0.7501 - accuracy: 0.7163 - val_loss: 0.8520 - val_accuracy: 0.6894 - lr: 7.0551e-13

# %%
import numpy as np

def pad_or_truncate(features, max_frames=200):
    num_frames, num_features = features.shape
    if num_frames >= max_frames:
        return features[:max_frames, :]
    else:
        padding = np.zeros((max_frames - num_frames, num_features))
        return np.vstack((features, padding))


from sklearn.preprocessing import StandardScaler

def standardize_features(X):
    num_samples, num_frames, num_features = X.shape
    X_reshaped = X.reshape(-1, num_features)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_reshaped)
    return X_scaled.reshape(num_samples, num_frames, num_features), scaler


from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_encoded = le.fit_transform(y)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Dropout, GlobalMaxPooling1D, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def create_cnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Conv1D(64, 3, activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv1D(128, 3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(GlobalMaxPooling1D())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer=tf.keras.optimizers.Adam(0.0003),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model


callbacks = [
    EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True),
    ModelCheckpoint('cnn_gemaps_model.h5', monitor='val_loss', save_best_only=True)
]
max_frames = 2000
num_features = feats_df.shape[1]
#X_train_padded = np.array([pad_or_truncate(feats) for feats in feats_df.values])
X_train_scaled = scaler.transform(X_train)
X_train_reshaped = X_train_scaled.reshape(-1, max_frames, num_features)
cnn_model = create_cnn_model(input_shape=(max_frames, num_features), num_classes=len(np.unique(y_encoded)))
cnn_model.fit(X_train, y_train_encoded, epochs=200, batch_size=16,
              validation_split=0.2, callbacks=callbacks)

# Evaluate the CNN model
cnn_loss, cnn_accuracy = cnn_model.evaluate(X_test, y_test_encoded)
print(f"CNN Test Loss: {cnn_loss}, Test Accuracy: {cnn_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 61
#      59 #X_train_padded = np.array([pad_or_truncate(feats) for feats in feats_df.values])
#      60 X_train_scaled = scaler.transform(X_train)
# ---> 61 X_train_reshaped = X_train_scaled.reshape(-1, max_frames, num_features)
#      62 cnn_model = create_cnn_model(input_shape=(max_frames, num_features), num_classes=len(np.unique(y_encoded)))
#      63 cnn_model.fit(X_train, y_train_encoded, epochs=200, batch_size=16,
#      64               validation_split=0.2, callbacks=callbacks)
#
# ValueError: cannot reshape array of size 195362 into shape (2000,62)

# %% [markdown]
# ### Experiment 1.3 – Apply SOTA or hybrid
#
# Reference Methods: Implement or replicate:
#
# [Zhao et al., 2019] CNN+Attention
#
# [Neumann & Vu, 2020] BiLSTM + Attention
#
# Compare to baseline: SVM + GeMAPS
#
# Dataset Augmentation: Try data balancing (SMOTE or oversampling)
