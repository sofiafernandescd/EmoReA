# %% [markdown]
# # A. Speech Emotion Recognition (SER) - Feature Selection
# Train and evaluated on isolated dataset with feature selection

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..', '..')) # or the path to your source code
sys.path.insert(0, module_path)
from src.data_loading import load_iemocap, load_meld, load_emodb, load_ravdess, load_tess, load_crema_d, filter_emotions

iemocap = filter_emotions(load_iemocap())
meld = filter_emotions(load_meld())
meld_train = filter_emotions(load_meld(split='train'))
emodb = filter_emotions(load_emodb())
ravdess = filter_emotions(load_ravdess())
tess = filter_emotions(load_tess())
crema_d = filter_emotions(load_crema_d())
# Out:
# Path to dataset files: /Users/krazmic/.cache/kagglehub/datasets/piyushagni5/berlin-database-of-emotional-speech-emodb/versions/1
# Path to dataset files: /Users/krazmic/.cache/kagglehub/datasets/uwrfkaggler/ravdess-emotional-speech-audio/versions/1
# Path to dataset files: /Users/krazmic/.cache/kagglehub/datasets/ejlok1/toronto-emotional-speech-set-tess/versions/1
# Path to dataset files: /Users/krazmic/.cache/kagglehub/datasets/ejlok1/cremad/versions/1

# %%
print(len(meld_train))
# drop row that contains "dia125_utt3" because the file is corrupted
meld_train = meld_train[meld_train['filename'].str.contains("dia125_utt3") == False]
print(len(meld_train))
# Out:
# 9989
# 9988

# %% [markdown]
# **1. GeMAPS (Geneva Minimalistic Acoustic Parameter Set):**

# %%
import opensmile
import pandas as pd

smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.Functionals,
    verbose=True
)

#iemocap_feats = smile.process_files(iemocap["filename"])
#emobd_feats = smile.process_files(emodb["filename"])
#ravdess_feats = smile.process_files(ravdess["filename"])
#tess_feats = smile.process_files(tess["filename"])
#crema_d_feats = smile.process_files(crema_d["filename"])

#iemocap_feats.to_csv("IEMOCAP_GeMAPS.csv", index=False)
#emobd_feats.to_csv("EMODB_GeMAPS.csv", index=False)
#ravdess_feats.to_csv("RAVDESS_GeMAPS.csv", index=False)
#tess_feats.to_csv("TESS_GeMAPS.csv", index=False)
#crema_d_feats.to_csv("CREMA-D_GeMAPS.csv", index=False)
#meld_feats = smile.process_files(meld_train["filename"])
#meld_feats.to_csv("MELD_train_GeMAPS.csv", index=False)

iemocap_feats = pd.read_csv("features/IEMOCAP_GeMAPS.csv")
emobd_feats = pd.read_csv("features/EMODB_GeMAPS.csv")
ravdess_feats = pd.read_csv("features/RAVDESS_GeMAPS.csv")
tess_feats = pd.read_csv("features/TESS_GeMAPS.csv")
crema_d_feats = pd.read_csv("features/CREMA-D_GeMAPS.csv")
meld_feats = pd.read_csv("features/MELD_GeMAPS.csv")
meld_train_feats = pd.read_csv("features/MELD_train_GeMAPS.csv")

# %%
emobd_feats.columns
# Out:
# Index(['F0semitoneFrom27.5Hz_sma3nz_amean',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevNorm',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile20.0',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile50.0',
#        'F0semitoneFrom27.5Hz_sma3nz_percentile80.0',
#        'F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2',
#        'F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope',
#        'F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope', 'loudness_sma3_amean',
#        'loudness_sma3_stddevNorm', 'loudness_sma3_percentile20.0',
#        'loudness_sma3_percentile50.0', 'loudness_sma3_percentile80.0',
#        'loudness_sma3_pctlrange0-2', 'loudness_sma3_meanRisingSlope',
#        'loudness_sma3_stddevRisingSlope', 'loudness_sma3_meanFallingSlope',
#        'loudness_sma3_stddevFallingSlope', 'jitterLocal_sma3nz_amean',
#        'jitterLocal_sma3nz_stddevNorm', 'shimmerLocaldB_sma3nz_amean',
#        'shimmerLocaldB_sma3nz_stddevNorm', 'HNRdBACF_sma3nz_amean',
#        'HNRdBACF_sma3nz_stddevNorm', 'logRelF0-H1-H2_sma3nz_amean',
#        'logRelF0-H1-H2_sma3nz_stddevNorm', 'logRelF0-H1-A3_sma3nz_amean',
#        'logRelF0-H1-A3_sma3nz_stddevNorm', 'F1frequency_sma3nz_amean',
#        'F1frequency_sma3nz_stddevNorm', 'F1bandwidth_sma3nz_amean',
#        'F1bandwidth_sma3nz_stddevNorm', 'F1amplitudeLogRelF0_sma3nz_amean',
#        'F1amplitudeLogRelF0_sma3nz_stddevNorm', 'F2frequency_sma3nz_amean',
#        'F2frequency_sma3nz_stddevNorm', 'F2amplitudeLogRelF0_sma3nz_amean',
#        'F2amplitudeLogRelF0_sma3nz_stddevNorm', 'F3frequency_sma3nz_amean',
#        'F3frequency_sma3nz_stddevNorm', 'F3amplitudeLogRelF0_sma3nz_amean',
#        'F3amplitudeLogRelF0_sma3nz_stddevNorm', 'alphaRatioV_sma3nz_amean',
#        'alphaRatioV_sma3nz_stddevNorm', 'hammarbergIndexV_sma3nz_amean',
#        'hammarbergIndexV_sma3nz_stddevNorm', 'slopeV0-500_sma3nz_amean',
#        'slopeV0-500_sma3nz_stddevNorm', 'slopeV500-1500_sma3nz_amean',
#        'slopeV500-1500_sma3nz_stddevNorm', 'alphaRatioUV_sma3nz_amean',
#        'hammarbergIndexUV_sma3nz_amean', 'slopeUV0-500_sma3nz_amean',
#        'slopeUV500-1500_sma3nz_amean', 'loudnessPeaksPerSec',
#        'VoicedSegmentsPerSec', 'MeanVoicedSegmentLengthSec',
#        'StddevVoicedSegmentLengthSec', 'MeanUnvoicedSegmentLength',
#        'StddevUnvoicedSegmentLength'],
#       dtype='object')

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, LeaveOneGroupOut
from sklearn.metrics import classification_report, confusion_matrix
from joblib import dump, load
import pandas as pd
from src.evaluation import plot_confusion_matrix
from src.select_features import FeatureSelector, plot_feature_mask#, plot_similarity_heatmap

# %%
X_train, X_test, y_train, y_test = train_test_split(
    meld_train_feats,
    meld_train['label'],
    test_size=0.2,
    random_state=42,
    stratify=meld_train['label']
)

# %%
fs_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection1', FeatureSelector(algorithm="algorithm1", L=0.80, dispersion_measure="MAD", similarity_measure="AC")),
    ('scaler2', StandardScaler()),
    ('feature_selection2', FeatureSelector(algorithm="algorithm2", L=0.95, MS=0.75, dispersion_measure="MAD", similarity_measure="AC")),
])

X_train = meld_train_feats
X_test = meld_feats
y_train = meld_train['label']
y_test = meld['label']

X_train_fs = fs_pipeline.fit_transform(X_train, y_train)
X_test_fs = fs_pipeline.transform(X_test)
# Out:
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.

# %%
X_test_fs.shape, X_train_fs.shape, X_train.shape, X_test.shape
# Out:
# ((2610, 46), (9988, 46), (9988, 62), (2610, 62))

# %%
# train and evaluate SVM
# no selection
svm = SVC(C=1.0, kernel='rbf', gamma='scale', random_state=42)
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
print("SVM without feature selection")
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
# SVM without feature selection
#               precision    recall  f1-score   support
#
#        angry       0.00      0.00      0.00       345
#      disgust       0.00      0.00      0.00        68
#         fear       0.00      0.00      0.00        50
#        happy       0.00      0.00      0.00       402
#      neutral       0.48      1.00      0.65      1256
#          sad       0.00      0.00      0.00       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.48      2610
#    macro avg       0.07      0.14      0.09      2610
# weighted avg       0.23      0.48      0.31      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fs_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection1', FeatureSelector(algorithm="algorithm1", L=0.80, dispersion_measure="MAD", similarity_measure="AC")),
    ('scaler2', StandardScaler()),
    ('feature_selection2', FeatureSelector(algorithm="algorithm2", L=0.95, MS=0.75, dispersion_measure="MAD", similarity_measure="AC")),
])

X_train = meld_train_feats
X_test = meld_feats
y_train = meld_train['label']
y_test = meld['label']

X_train_fs = fs_pipeline.fit_transform(X_train, y_train)
X_test_fs = fs_pipeline.transform(X_test)
print(X_test_fs.shape, X_train_fs.shape, X_train.shape, X_test.shape)

# train and evaluate SVM
# no selection
svm_fs = SVC(C=1.0, kernel='rbf', gamma='scale', random_state=42)
svm_fs.fit(X_train_fs, y_train)
y_pred_fs = svm_fs.predict(X_test_fs)
print("SVM without feature selection")
print(classification_report(y_test, y_pred_fs))
plot_confusion_matrix(y_test, y_pred_fs)
# Out:
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# (2610, 46) (9988, 46) (9988, 62) (2610, 62)
# SVM without feature selection
#               precision    recall  f1-score   support
#
#        angry       0.55      0.02      0.03       345
#      disgust       0.00      0.00      0.00        68
#         fear       0.00      0.00      0.00        50
#        happy       0.14      0.00      0.00       402
#      neutral       0.48      1.00      0.65      1256
#          sad       0.00      0.00      0.00       208
#     surprise       0.67      0.01      0.01       281
#
#     accuracy                           0.48      2610
#    macro avg       0.26      0.15      0.10      2610
# weighted avg       0.40      0.48      0.32      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Best parameters (RF): {'rf__max_depth': 20, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200, min_samples_split=2, min_samples_leaf=1, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print("Random Forest without feature selection")
print(classification_report(y_test, y_pred_rf))
plot_confusion_matrix(y_test, y_pred_rf)
# Out:
# Random Forest without feature selection
#               precision    recall  f1-score   support
#
#        angry       0.37      0.08      0.14       345
#      disgust       0.00      0.00      0.00        68
#         fear       0.00      0.00      0.00        50
#        happy       0.27      0.05      0.08       402
#      neutral       0.50      0.97      0.66      1256
#          sad       0.00      0.00      0.00       208
#     surprise       0.29      0.04      0.06       281
#
#     accuracy                           0.49      2610
#    macro avg       0.20      0.16      0.14      2610
# weighted avg       0.36      0.49      0.36      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rf_fs = RandomForestClassifier(n_estimators=200, min_samples_split=2, min_samples_leaf=1, random_state=42)
rf_fs.fit(X_train_fs, y_train)
y_pred_rf_fs = rf_fs.predict(X_test_fs)
print("Random Forest with feature selection")
print(classification_report(y_test, y_pred_rf_fs))
plot_confusion_matrix(y_test, y_pred_rf_fs)
# Out:
# Random Forest with feature selection
#               precision    recall  f1-score   support
#
#        angry       0.38      0.08      0.13       345
#      disgust       0.00      0.00      0.00        68
#         fear       0.00      0.00      0.00        50
#        happy       0.25      0.04      0.08       402
#      neutral       0.50      0.97      0.66      1256
#          sad       0.50      0.00      0.01       208
#     surprise       0.36      0.05      0.08       281
#
#     accuracy                           0.49      2610
#    macro avg       0.28      0.16      0.14      2610
# weighted avg       0.41      0.49      0.36      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Best parameters (LogReg): {'logreg__C': 0.1, 'logreg__penalty': 'l2', 'logreg__solver': 'lbfgs'
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(C=0.1, penalty='l2', solver='lbfgs', max_iter=5000, random_state=42)
logreg.fit(X_train, y_train)
y_pred_logreg = logreg.predict(X_test)
print("Logistic Regression without feature selection")
print(classification_report(y_test, y_pred_logreg))
plot_confusion_matrix(y_test, y_pred_logreg)
# Out:
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression without feature selection
#               precision    recall  f1-score   support
#
#        angry       0.33      0.04      0.07       345
#      disgust       0.00      0.00      0.00        68
#         fear       0.00      0.00      0.00        50
#        happy       0.17      0.01      0.03       402
#      neutral       0.49      0.97      0.65      1256
#          sad       0.00      0.00      0.00       208
#     surprise       0.27      0.03      0.05       281
#
#     accuracy                           0.48      2610
#    macro avg       0.18      0.15      0.11      2610
# weighted avg       0.33      0.48      0.33      2610

# %%
lr_fs = LogisticRegression(C=0.1, penalty='l2', solver='lbfgs', max_iter=5000, random_state=42)
lr_fs.fit(X_train_fs, y_train)
y_pred_lr_fs = lr_fs.predict(X_test_fs)
print("Logistic Regression with feature selection")
print(classification_report(y_test, y_pred_lr_fs))
plot_confusion_matrix(y_test, y_pred_lr_fs)
# Out:
# Logistic Regression with feature selection
#               precision    recall  f1-score   support
#
#        angry       0.35      0.04      0.08       345
#      disgust       0.00      0.00      0.00        68
#         fear       0.00      0.00      0.00        50
#        happy       0.29      0.03      0.05       402
#      neutral       0.49      0.97      0.65      1256
#          sad       0.00      0.00      0.00       208
#     surprise       0.24      0.03      0.05       281
#
#     accuracy                           0.48      2610
#    macro avg       0.20      0.15      0.12      2610
# weighted avg       0.35      0.48      0.34      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_feature_mask(fs_pipeline.named_steps['feature_selection1'].selected_indices, title="Feature Mask - Step 1")
plot_feature_mask(fs_pipeline.named_steps['feature_selection2'].selected_indices, title="Feature Mask - Step 2")
#plot_similarity_heatmap(fs_pipeline.named_steps['feature_selection1'].similarity_matrix_, title="Similarity Heatmap - Step 1")
#plot_similarity_heatmap(fs_pipeline.named_steps['feature_selection2'].similarity_matrix_, title="Similarity Heatmap - Step 2")

# %% [markdown]
# # SVM

# %%
# SVM pipeline
svm_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection1', FeatureSelector(algorithm="algorithm1", L=0.80, dispersion_measure="MAD", similarity_measure="AC")),
    ('scaler2', StandardScaler()),
    ('feature_selection2', FeatureSelector(algorithm="algorithm2", L=0.95, MS=0.75, dispersion_measure="MAD", similarity_measure="AC")),
    ('svm', SVC()),
])

# Hyperparameter tuning
param_grid = {
    'svm__C': [0.1, 1, 10, 50],
    'svm__kernel': ['linear', 'rbf'],
    'svm__gamma': ['scale', 'auto'],
}

X_train, X_test, y_train, y_test = train_test_split(
    meld_feats,
    meld['label'],
    test_size=0.2,
    random_state=42,
    stratify=meld['label']
)

grid_search = GridSearchCV(svm_pipeline, param_grid, cv=10, n_jobs=-1, verbose=0)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_) 
print("Best cross-validation score:", grid_search.best_score_)
# save the best model
dump(grid_search.best_estimator_, 'svm_M_FS.joblib')
# Access the results
results = grid_search.cv_results_

# Print the mean and standard deviation for each hyperparameter combination
for mean, std, params in zip(results['mean_test_score'], results['std_test_score'], results['params']):
    print(f"Mean Score: {mean:.3f}, Std Dev: {std:.3f}, Parameters: {params}")
# Out:
# Best parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.48754830695620166
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.488, Std Dev: 0.006, Parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.488, Std Dev: 0.006, Parameters: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.436, Std Dev: 0.032, Parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.436, Std Dev: 0.032, Parameters: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.353, Std Dev: 0.030, Parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.481, Std Dev: 0.002, Parameters: {'svm__C': 50, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.353, Std Dev: 0.030, Parameters: {'svm__C': 50, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}

# %%
best_model = load('svm_M_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.67      0.12      0.20        69
#      disgust       0.00      0.00      0.00        14
#         fear       0.00      0.00      0.00        10
#        happy       0.00      0.00      0.00        80
#      neutral       0.49      1.00      0.66       251
#          sad       0.00      0.00      0.00        42
#     surprise       0.00      0.00      0.00        56
#
#     accuracy                           0.49       522
#    macro avg       0.17      0.16      0.12       522
# weighted avg       0.32      0.49      0.34       522

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from joblib import dump, load
import pandas as pd
from src.evaluation import plot_confusion_matrix
from src.select_features import FeatureSelector

# SVM pipeline
svm_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection1', FeatureSelector(algorithm="algorithm1", L=0.80, dispersion_measure="MAD", similarity_measure="AC")),
    ('scaler2', StandardScaler()),
    ('feature_selection2', FeatureSelector(algorithm="algorithm2", L=0.95, MS=0.75, dispersion_measure="MAD", similarity_measure="AC")),
    ('svm', SVC()),
])

# Hyperparameter tuning
param_grid = {
    'svm__C': [0.1, 1, 10, 50, 100],
    'svm__kernel': ['linear', 'rbf'],
    'svm__gamma': ['scale', 'auto'],
}



#X_train = pd.concat([emobd_feats, ravdess_feats, tess_feats, crema_d_feats])
#y_train = pd.concat([emodb['label'], ravdess['label'], tess['label'], crema_d['label']])
#X_test = iemocap_feats
#y_test = iemocap['label']
X_train, X_test, y_train, y_test = train_test_split(
    emobd_feats,
    emodb['label'],
    test_size=0.2,
    random_state=42,
    stratify=emodb['label']
)

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
grid_search = GridSearchCV(svm_pipeline, param_grid, cv=cv, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# save the best model
dump(grid_search.best_estimator_, 'svm_E_FS.joblib')
# Access the results
results = grid_search.cv_results_

# Print the mean and standard deviation for each hyperparameter combination
for mean, std, params in zip(results['mean_test_score'], results['std_test_score'], results['params']):
    print(f"Mean Score: {mean:.3f}, Std Dev: {std:.3f}, Parameters: {params}")

print("Best parameters:", grid_search.best_params_) 
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.Alg. 1: Selected top 49 features out of 62 total features.
#
# Alg. 2: Selected 44 features out of 49 total features.[CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
#
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.[CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
#
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.Alg. 2: Selected 46 features out of 49 total features.
#
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0sAlg. 2: Selected 44 features out of 49 total features.
#
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Mean Score: 0.749, Std Dev: 0.076, Parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.551, Std Dev: 0.035, Parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.749, Std Dev: 0.076, Parameters: {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.551, Std Dev: 0.035, Parameters: {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.730, Std Dev: 0.063, Parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.763, Std Dev: 0.065, Parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.730, Std Dev: 0.063, Parameters: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.763, Std Dev: 0.065, Parameters: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.733, Std Dev: 0.075, Parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.785, Std Dev: 0.052, Parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.733, Std Dev: 0.075, Parameters: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.785, Std Dev: 0.052, Parameters: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.739, Std Dev: 0.083, Parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.785, Std Dev: 0.052, Parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.739, Std Dev: 0.083, Parameters: {'svm__C': 50, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.785, Std Dev: 0.052, Parameters: {'svm__C': 50, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.739, Std Dev: 0.084, Parameters: {'svm__C': 100, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.785, Std Dev: 0.052, Parameters: {'svm__C': 100, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.739, Std Dev: 0.084, Parameters: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.785, Std Dev: 0.052, Parameters: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Best parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.7851351351351352

# %% [markdown]
# Best parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
#
# Best cross-validation score: 0.787987987987988

# %%
best_model = load('svm_E_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.15      0.04      0.06       345
#      disgust       0.00      0.00      0.00        68
#         fear       0.02      0.84      0.04        50
#        happy       0.15      0.12      0.13       402
#      neutral       0.50      0.00      0.00      1256
#          sad       0.18      0.01      0.02       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.04      2610
#    macro avg       0.14      0.14      0.04      2610
# weighted avg       0.30      0.04      0.03      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
best_model = load('svm_E_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.84      0.81      0.82        26
#      disgust       0.78      0.78      0.78         9
#         fear       0.93      0.93      0.93        14
#        happy       0.64      0.64      0.64        14
#      neutral       0.93      0.81      0.87        16
#          sad       0.80      1.00      0.89        12
#
#     accuracy                           0.82        91
#    macro avg       0.82      0.83      0.82        91
# weighted avg       0.83      0.82      0.82        91

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.75      0.24      0.37      1103
#      disgust       0.00      0.00      0.00         2
#         fear       0.01      0.60      0.02        40
#        happy       0.20      0.16      0.18       595
#      neutral       0.58      0.01      0.02      1708
#          sad       0.36      0.54      0.44      1084
#     surprise       0.00      0.00      0.00       107
#
#     accuracy                           0.21      4639
#    macro avg       0.27      0.22      0.15      4639
# weighted avg       0.50      0.21      0.22      4639

# %% [markdown]
# # Validate parameter ranges
# # Paper recommendations
#     if not 0.7 <= L <= 0.9:
#         print(f"Warning: L={L:.2f} outside recommended [0.7, 0.9] range")
#
#     if not 0.7 <= L <= 0.99:
#         print(f"Warning: L={L:.2f} outside recommended [0.7, 0.99] range")
#     if not 0.7 <= MS <= 0.8:
#         print(f"Warning: MS={MS:.2f} outside recommended [0.7, 0.8] range")

# %%
# SVM pipeline
svm_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection1', FeatureSelector(algorithm="algorithm1", L=0.80, dispersion_measure="MAD", similarity_measure="AC")),
    ('scaler2', StandardScaler()),
    ('feature_selection2', FeatureSelector(algorithm="algorithm2", L=0.95, MS=0.75, dispersion_measure="MAD", similarity_measure="AC")),
    ('svm', SVC()),
])

X_train, X_test, y_train, y_test = train_test_split(
    ravdess_feats,
    ravdess['label'],
    test_size=0.2,
    random_state=42,
    stratify=ravdess['label']
)

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
grid_search = GridSearchCV(svm_pipeline, param_grid, cv=cv, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# save the best model
dump(grid_search.best_estimator_, 'svm_R_FS.joblib')
# Access the results
results = grid_search.cv_results_
# Print the mean and standard deviation for each hyperparameter combination
for mean, std, params in zip(results['mean_test_score'], results['std_test_score'], results['params']):
    print(f"Mean Score: {mean:.3f}, Std Dev: {std:.3f}, Parameters: {params}")

print("Best parameters:", grid_search.best_params_) 
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 35 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 39 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 2: Selected 39 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 2: Selected 35 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.5s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   3.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   3.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   3.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   3.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   3.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   3.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   3.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   3.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   2.3s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   3.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   3.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   8.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   9.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   3.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   2.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   3.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   6.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   5.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   5.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   7.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   9.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   6.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   5.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   6.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   8.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 39 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 36 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 37 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   6.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 33 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   6.8s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   6.3s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   6.3s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   7.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   7.5s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   5.6s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   4.4s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   5.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 35 features out of 49 total features.
# Mean Score: 0.546, Std Dev: 0.054, Parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.486, Std Dev: 0.064, Parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.546, Std Dev: 0.054, Parameters: {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.486, Std Dev: 0.064, Parameters: {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.558, Std Dev: 0.042, Parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.589, Std Dev: 0.063, Parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.558, Std Dev: 0.042, Parameters: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.589, Std Dev: 0.063, Parameters: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.540, Std Dev: 0.052, Parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.632, Std Dev: 0.053, Parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.540, Std Dev: 0.052, Parameters: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.632, Std Dev: 0.053, Parameters: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.553, Std Dev: 0.045, Parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.636, Std Dev: 0.048, Parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.553, Std Dev: 0.045, Parameters: {'svm__C': 50, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.636, Std Dev: 0.048, Parameters: {'svm__C': 50, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.551, Std Dev: 0.054, Parameters: {'svm__C': 100, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.636, Std Dev: 0.048, Parameters: {'svm__C': 100, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.551, Std Dev: 0.054, Parameters: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.636, Std Dev: 0.048, Parameters: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Best parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.6363030303030304

# %% [markdown]
# Best parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.6342828282828283

# %%
best_model = load('svm_R_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.73      0.63      0.68        38
#      disgust       0.62      0.61      0.61        38
#         fear       0.54      0.49      0.51        39
#        happy       0.52      0.67      0.58        39
#      neutral       0.52      0.63      0.57        19
#          sad       0.60      0.54      0.57        39
#     surprise       0.59      0.58      0.59        38
#
#     accuracy                           0.59       250
#    macro avg       0.59      0.59      0.59       250
# weighted avg       0.59      0.59      0.59       250

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.89      0.01      0.01      1103
#      disgust       0.00      0.50      0.00         2
#         fear       0.02      0.03      0.02        40
#        happy       0.13      0.16      0.14       595
#      neutral       0.38      0.00      0.01      1708
#          sad       0.31      0.80      0.45      1084
#     surprise       0.14      0.07      0.09       107
#
#     accuracy                           0.21      4639
#    macro avg       0.27      0.22      0.10      4639
# weighted avg       0.45      0.21      0.13      4639

# %%
best_model = load('svm_R_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.00      0.00      0.00       345
#      disgust       0.03      0.13      0.05        68
#         fear       0.00      0.00      0.00        50
#        happy       0.14      0.02      0.04       402
#      neutral       0.00      0.00      0.00      1256
#          sad       0.08      0.83      0.14       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.07      2610
#    macro avg       0.03      0.14      0.03      2610
# weighted avg       0.03      0.07      0.02      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# SVM pipeline
svm_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection1', FeatureSelector(algorithm="algorithm1", L=0.80, dispersion_measure="MAD", similarity_measure="AC")),
    ('scaler2', StandardScaler()),
    ('feature_selection2', FeatureSelector(algorithm="algorithm2", L=0.95, MS=0.75, dispersion_measure="MAD", similarity_measure="AC")),
    ('svm', SVC()),
])

X_train, X_test, y_train, y_test = train_test_split(
    tess_feats,
    tess['label'],
    test_size=0.2,
    random_state=42,
    stratify=tess['label']
)

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
grid_search = GridSearchCV(svm_pipeline, param_grid, cv=cv, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# save the best model
dump(grid_search.best_estimator_, 'svm_T_FS.joblib')
# Access the results
results = grid_search.cv_results_

# Print the mean and standard deviation for each hyperparameter combination
for mean, std, params in zip(results['mean_test_score'], results['std_test_score'], results['params']):
    print(f"Mean Score: {mean:.3f}, Std Dev: {std:.3f}, Parameters: {params}")

print("Best parameters:", grid_search.best_params_) 
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s[CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
#
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   0.2s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.1sAlg. 1: Selected top 49 features out of 62 total features.
#
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.Alg. 1: Selected top 49 features out of 62 total features.
#
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.0s
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   0.1s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Mean Score: 0.982, Std Dev: 0.006, Parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.969, Std Dev: 0.011, Parameters: {'svm__C': 0.1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.982, Std Dev: 0.006, Parameters: {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.969, Std Dev: 0.011, Parameters: {'svm__C': 0.1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.981, Std Dev: 0.007, Parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.990, Std Dev: 0.004, Parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.981, Std Dev: 0.007, Parameters: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.990, Std Dev: 0.004, Parameters: {'svm__C': 1, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.979, Std Dev: 0.008, Parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.992, Std Dev: 0.005, Parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.979, Std Dev: 0.008, Parameters: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.992, Std Dev: 0.005, Parameters: {'svm__C': 10, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.977, Std Dev: 0.009, Parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.992, Std Dev: 0.005, Parameters: {'svm__C': 50, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.977, Std Dev: 0.009, Parameters: {'svm__C': 50, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.992, Std Dev: 0.005, Parameters: {'svm__C': 50, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Mean Score: 0.976, Std Dev: 0.010, Parameters: {'svm__C': 100, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Mean Score: 0.992, Std Dev: 0.005, Parameters: {'svm__C': 100, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Mean Score: 0.976, Std Dev: 0.010, Parameters: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'linear'}
# Mean Score: 0.992, Std Dev: 0.005, Parameters: {'svm__C': 100, 'svm__gamma': 'auto', 'svm__kernel': 'rbf'}
# Best parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.9924107142857143

# %% [markdown]
# Best parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.9888392857142858

# %%
best_model = load('svm_T_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       1.00      1.00      1.00        80
#      disgust       0.99      1.00      0.99        80
#         fear       1.00      1.00      1.00        80
#        happy       0.98      0.99      0.98        80
#      neutral       1.00      1.00      1.00        80
#          sad       1.00      1.00      1.00        80
#     surprise       0.99      0.96      0.97        80
#
#     accuracy                           0.99       560
#    macro avg       0.99      0.99      0.99       560
# weighted avg       0.99      0.99      0.99       560

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.70      0.04      0.08      1103
#      disgust       0.00      0.50      0.00         2
#         fear       0.01      0.78      0.02        40
#        happy       0.00      0.00      0.00       595
#      neutral       1.00      0.00      0.00      1708
#          sad       0.00      0.00      0.00      1084
#     surprise       0.02      0.05      0.03       107
#
#     accuracy                           0.02      4639
#    macro avg       0.25      0.20      0.02      4639
# weighted avg       0.53      0.02      0.02      4639
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
best_model = load('svm_T_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.15      0.15      0.15       345
#      disgust       0.03      0.10      0.04        68
#         fear       0.02      0.74      0.04        50
#        happy       0.00      0.00      0.00       402
#      neutral       0.00      0.00      0.00      1256
#          sad       0.00      0.00      0.00       208
#     surprise       0.11      0.02      0.03       281
#
#     accuracy                           0.04      2610
#    macro avg       0.04      0.14      0.04      2610
# weighted avg       0.03      0.04      0.02      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    crema_d_feats,
    crema_d['label'],
    test_size=0.2,
    random_state=42,
    stratify=crema_d['label']
)

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
grid_search = GridSearchCV(svm_pipeline, param_grid, cv=cv, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_) 
print("Best cross-validation score:", grid_search.best_score_)
# save the best model
dump(grid_search.best_estimator_, 'svm_C_FS.joblib')
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.Alg. 2: Selected 41 features out of 49 total features.
#
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.0s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.1s
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.1s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.5s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   0.9s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.3s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.1s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.4s
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.0s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  11.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  11.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  10.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  10.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  11.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  11.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  11.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  11.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  10.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  10.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  10.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  10.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  10.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=   9.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  10.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  11.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   1.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  11.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  11.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  10.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  10.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  47.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  48.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  48.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  45.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  50.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  47.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.0s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  48.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  48.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  45.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=  47.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  45.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  44.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  46.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  45.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  47.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  48.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  47.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  47.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  45.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=  48.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.5min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.6min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.6min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.7min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ......svm__C=100, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.5min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.5min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.6min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.7min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.6min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ...svm__C=100, svm__gamma=scale, svm__kernel=linear; total time= 1.7min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.5min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.6min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.4min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.6min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.6min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.4min
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# [CV] END .......svm__C=100, svm__gamma=auto, svm__kernel=rbf; total time=   2.1s
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.3min
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.4min
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.3min
# [CV] END ....svm__C=100, svm__gamma=auto, svm__kernel=linear; total time= 1.4min
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Best parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.5084868309740003
# ['svm_C_FS.joblib']

# %% [markdown]
# Best parameters: {'svm__C': 10, 'svm__gamma': 'scale', 'svm__kernel': 'linear'}
# Best cross-validation score: 0.5143624161073825

# %%
best_model = load('svm_C_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.70      0.76      0.73       254
#      disgust       0.48      0.43      0.45       254
#         fear       0.49      0.39      0.44       254
#        happy       0.54      0.48      0.51       255
#      neutral       0.50      0.54      0.52       218
#          sad       0.48      0.60      0.53       254
#
#     accuracy                           0.53      1489
#    macro avg       0.53      0.53      0.53      1489
# weighted avg       0.53      0.53      0.53      1489

# %%
best_model = load('svm_C_FS.joblib')
# meld
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.13      0.06      0.08       345
#      disgust       0.03      0.18      0.05        68
#         fear       0.00      0.00      0.00        50
#        happy       0.11      0.00      0.01       402
#      neutral       0.33      0.00      0.00      1256
#          sad       0.08      0.75      0.14       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.07      2610
#    macro avg       0.10      0.14      0.04      2610
# weighted avg       0.20      0.07      0.03      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.72      0.46      0.56      1103
#      disgust       0.00      0.50      0.00         2
#         fear       0.02      0.25      0.03        40
#        happy       0.16      0.09      0.12       595
#      neutral       0.68      0.14      0.24      1708
#          sad       0.44      0.23      0.30      1084
#     surprise       0.00      0.00      0.00       107
#
#     accuracy                           0.23      4639
#    macro avg       0.29      0.24      0.18      4639
# weighted avg       0.54      0.23      0.30      4639

# %%
X_train, X_test, y_train, y_test = train_test_split(
    iemocap_feats,
    iemocap['label'],
    test_size=0.2,
    random_state=42,
    stratify=iemocap['label']
)

grid_search = GridSearchCV(svm_pipeline, param_grid, cv=10, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_) 
print("Best cross-validation score:", grid_search.best_score_)
# save the best model
dump(grid_search.best_estimator_, 'svm_I_FS.joblib')
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.8s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.8s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.9s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.9s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.9s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.9s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.9s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.9s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   1.9s
# [CV] END ...svm__C=0.1, svm__gamma=scale, svm__kernel=linear; total time=   2.0s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.6s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.8s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.9s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.8s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.9s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.7s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.7s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.8s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.7s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.8s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.8s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.8s
# [CV] END ......svm__C=0.1, svm__gamma=scale, svm__kernel=rbf; total time=   2.8s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.8s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.7s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.7s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.7s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.7s
# [CV] END ....svm__C=0.1, svm__gamma=auto, svm__kernel=linear; total time=   1.9s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.3s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# [CV] END .......svm__C=0.1, svm__gamma=auto, svm__kernel=rbf; total time=   2.3s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   3.3s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   3.9s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   3.4s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   3.7s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   3.8s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   3.9s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   3.9s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   4.2s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   3.7s
# [CV] END .....svm__C=1, svm__gamma=scale, svm__kernel=linear; total time=   4.0s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.4s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.2s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.2s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.3s
# [CV] END ........svm__C=1, svm__gamma=scale, svm__kernel=rbf; total time=   2.2s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.4s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.8s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.1s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.6s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.5s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.2s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.6s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.5s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.8s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   3.8s
# [CV] END ......svm__C=1, svm__gamma=auto, svm__kernel=linear; total time=   4.1s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.1s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.1s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.2s
# [CV] END .........svm__C=1, svm__gamma=auto, svm__kernel=rbf; total time=   2.3s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.6s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.6s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.5s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.6s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.7s
# [CV] END .......svm__C=10, svm__gamma=scale, svm__kernel=rbf; total time=   2.7s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  17.5s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  17.6s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  17.2s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  17.1s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  18.5s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  19.3s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  21.1s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  20.3s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  21.7s
# [CV] END ....svm__C=10, svm__gamma=scale, svm__kernel=linear; total time=  22.6s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.6s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.6s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.6s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.5s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  17.1s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.4s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.6s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.6s
# [CV] END ........svm__C=10, svm__gamma=auto, svm__kernel=rbf; total time=   2.7s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  16.9s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  17.4s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  21.3s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  18.0s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  18.9s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  16.9s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  20.9s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  20.9s
# [CV] END .....svm__C=10, svm__gamma=auto, svm__kernel=linear; total time=  23.6s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   4.7s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   4.8s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   5.3s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   5.3s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   5.9s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   5.9s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   5.4s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   5.4s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   5.6s
# [CV] END .......svm__C=50, svm__gamma=scale, svm__kernel=rbf; total time=   5.4s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time= 3.0min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time= 2.8min
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time= 6.1min
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time= 6.2min
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time= 6.5min
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time= 7.0min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time= 6.8min
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time= 8.7min
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=10.9min
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   4.3s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   3.5s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=   7.6s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=  11.9s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=  11.6s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=  11.7s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=  11.6s
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=41.9min
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=  11.2s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=  11.3s
# [CV] END ........svm__C=50, svm__gamma=auto, svm__kernel=rbf; total time=  10.6s
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=37.8min
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=44.5min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=39.1min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=38.8min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=42.4min
# [CV] END ....svm__C=50, svm__gamma=scale, svm__kernel=linear; total time=50.9min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=45.0min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=50.8min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=46.5min
# [CV] END .....svm__C=50, svm__gamma=auto, svm__kernel=linear; total time=44.7min
# Best parameters: {'svm__C': 1, 'svm__gamma': 'scale', 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.6181621887951773
# ['svm_I_FS.joblib']

# %%
best_model = load('svm_I_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.74      0.70      0.72       221
#         fear       0.00      0.00      0.00         8
#        happy       0.60      0.03      0.05       119
#      neutral       0.57      0.81      0.67       342
#          sad       0.68      0.71      0.70       217
#     surprise       0.00      0.00      0.00        21
#
#     accuracy                           0.64       928
#    macro avg       0.43      0.38      0.36       928
# weighted avg       0.62      0.64      0.59       928

# %% [markdown]
# # Random Forest

# %%
# Grid search with Random Forest
from sklearn.ensemble import RandomForestClassifier
rf_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection1', FeatureSelector(algorithm="algorithm1", L=0.80, dispersion_measure="MAD", similarity_measure="AC")),
    ('scaler2', StandardScaler()),
    ('feature_selection2', FeatureSelector(algorithm="algorithm2", L=0.95, MS=0.75, dispersion_measure="MAD", similarity_measure="AC")),
    ('rf', RandomForestClassifier()),
])
grid_param = {
    'rf__n_estimators': [100, 200],
    'rf__max_depth': [None, 10, 20],
    'rf__min_samples_split': [2, 5],
    'rf__min_samples_leaf': [1, 2],
}


X_train, X_test, y_train, y_test = train_test_split(
    emobd_feats,
    emodb['label'],
    test_size=0.2,
    random_state=42,
    stratify=emodb['label']
)

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
grid_search_rf = GridSearchCV(rf_pipeline, grid_param, cv=cv, n_jobs=-1, verbose=2)
grid_search_rf.fit(X_train, y_train)
print("Best parameters (RF):", grid_search_rf.best_params_) 
print("Best cross-validation score (RF):", grid_search_rf.best_score_)
dump(grid_search_rf.best_estimator_, 'rf_E_FS.joblib')
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.Alg. 1: Selected top 49 features out of 62 total features.
#
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.1s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Best parameters (RF): {'rf__max_depth': 10, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}
# Best cross-validation score (RF): 0.737987987987988
# ['rf_E_FS.joblib']

# %%
best_model = load('rf_E_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.70      0.81      0.75        26
#      disgust       0.86      0.67      0.75         9
#         fear       0.89      0.57      0.70        14
#        happy       0.50      0.43      0.46        14
#      neutral       0.80      1.00      0.89        16
#          sad       0.92      1.00      0.96        12
#
#     accuracy                           0.76        91
#    macro avg       0.78      0.75      0.75        91
# weighted avg       0.76      0.76      0.75        91

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.67      0.45      0.54      1103
#      disgust       0.00      0.50      0.00         2
#         fear       0.04      0.17      0.06        40
#        happy       0.18      0.11      0.14       595
#      neutral       0.67      0.05      0.09      1708
#          sad       0.47      0.55      0.51      1084
#     surprise       0.00      0.00      0.00       107
#
#     accuracy                           0.27      4639
#    macro avg       0.29      0.26      0.19      4639
# weighted avg       0.54      0.27      0.30      4639

# %%
best_model = load('rf_E_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.17      0.70      0.27       345
#      disgust       0.02      0.07      0.03        68
#         fear       0.01      0.02      0.01        50
#        happy       0.16      0.18      0.17       402
#      neutral       0.51      0.08      0.14      1256
#          sad       0.10      0.03      0.04       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.16      2610
#    macro avg       0.14      0.15      0.09      2610
# weighted avg       0.30      0.16      0.13      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    ravdess_feats,
    ravdess['label'],
    test_size=0.2,
    random_state=42,
    stratify=ravdess['label']
)

grid_search_rf = GridSearchCV(rf_pipeline, grid_param, cv=10, n_jobs=-1, verbose=2)
grid_search_rf.fit(X_train, y_train)
print("Best parameters (RF):", grid_search_rf.best_params_) 
print("Best cross-validation score (RF):", grid_search_rf.best_score_)
dump(grid_search_rf.best_estimator_, 'rf_R_FS.joblib')
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   1.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   1.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   1.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   1.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   1.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   1.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   2.2s
# Best parameters (RF): {'rf__max_depth': 20, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}
# Best cross-validation score (RF): 0.589010101010101
# ['rf_R_FS.joblib']

# %%
best_model = load('rf_R_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.72      0.55      0.63        38
#      disgust       0.50      0.50      0.50        38
#         fear       0.56      0.38      0.45        39
#        happy       0.42      0.54      0.47        39
#      neutral       0.48      0.53      0.50        19
#          sad       0.49      0.54      0.51        39
#     surprise       0.57      0.63      0.60        38
#
#     accuracy                           0.52       250
#    macro avg       0.53      0.52      0.52       250
# weighted avg       0.54      0.52      0.52       250

# %%
best_model = load('rf_R_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.17      0.16      0.17       345
#      disgust       0.02      0.37      0.04        68
#         fear       0.02      0.06      0.02        50
#        happy       0.15      0.24      0.19       402
#      neutral       0.50      0.00      0.00      1256
#          sad       0.10      0.15      0.12       208
#     surprise       0.12      0.01      0.02       281
#
#     accuracy                           0.08      2610
#    macro avg       0.15      0.14      0.08      2610
# weighted avg       0.31      0.08      0.07      2610

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.96      0.08      0.14      1103
#      disgust       0.00      0.00      0.00         2
#         fear       0.02      0.12      0.03        40
#        happy       0.18      0.23      0.21       595
#      neutral       0.59      0.03      0.05      1708
#          sad       0.37      0.88      0.52      1084
#     surprise       0.08      0.07      0.07       107
#
#     accuracy                           0.27      4639
#    macro avg       0.32      0.20      0.15      4639
# weighted avg       0.56      0.27      0.20      4639

# %%
X_train, X_test, y_train, y_test = train_test_split(
    tess_feats,
    tess['label'],
    test_size=0.2,
    random_state=42,
    stratify=tess['label']
)

grid_search_rf = GridSearchCV(rf_pipeline, grid_param, cv=10, n_jobs=-1, verbose=2)
grid_search_rf.fit(X_train, y_train)
print("Best parameters (RF):", grid_search_rf.best_params_) 
print("Best cross-validation score (RF):", grid_search_rf.best_score_)
dump(grid_search_rf.best_estimator_, 'rf_T_FS.joblib')
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.1s
# Best parameters (RF): {'rf__max_depth': None, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}
# Best cross-validation score (RF): 0.9870535714285713
# ['rf_T_FS.joblib']

# %%
best_model = load('rf_T_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.99      1.00      0.99        80
#      disgust       0.98      1.00      0.99        80
#         fear       0.99      0.99      0.99        80
#        happy       0.99      0.97      0.98        80
#      neutral       1.00      1.00      1.00        80
#          sad       1.00      1.00      1.00        80
#     surprise       0.99      0.96      0.97        80
#
#     accuracy                           0.99       560
#    macro avg       0.99      0.99      0.99       560
# weighted avg       0.99      0.99      0.99       560

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.38      0.21      0.27      1103
#      disgust       0.00      1.00      0.00         2
#         fear       0.02      0.17      0.03        40
#        happy       0.12      0.02      0.03       595
#      neutral       0.35      0.06      0.10      1708
#          sad       0.37      0.01      0.02      1084
#     surprise       0.04      0.09      0.06       107
#
#     accuracy                           0.08      4639
#    macro avg       0.18      0.22      0.07      4639
# weighted avg       0.32      0.08      0.11      4639

# %%
best_model = load('rf_T_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.17      0.21      0.19       345
#      disgust       0.02      0.50      0.04        68
#         fear       0.03      0.20      0.05        50
#        happy       0.00      0.00      0.00       402
#      neutral       0.65      0.03      0.06      1256
#          sad       1.00      0.00      0.01       208
#     surprise       0.17      0.11      0.14       281
#
#     accuracy                           0.07      2610
#    macro avg       0.29      0.15      0.07      2610
# weighted avg       0.43      0.07      0.07      2610

# %%
X_train, X_test, y_train, y_test = train_test_split(
    crema_d_feats,
    crema_d['label'],
    test_size=0.2,
    random_state=42,
    stratify=crema_d['label']
)

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
grid_search_rf = GridSearchCV(rf_pipeline, grid_param, cv=cv, n_jobs=-1, verbose=2)
grid_search_rf.fit(X_train, y_train)
print("Best parameters (RF):", grid_search_rf.best_params_) 
print("Best cross-validation score (RF):", grid_search_rf.best_score_)
dump(grid_search_rf.best_estimator_, 'rf_C_FS.joblib')
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.4s
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   6.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.8s
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.8s
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   1.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   3.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   5.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   5.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   2.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   4.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Best parameters (RF): {'rf__max_depth': 20, 'rf__min_samples_leaf': 2, 'rf__min_samples_split': 2, 'rf__n_estimators': 100}
# Best cross-validation score (RF): 0.49958406181264453
# ['rf_C_FS.joblib']

# %%
best_model = load('rf_C_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.64      0.73      0.68       254
#      disgust       0.45      0.33      0.38       254
#         fear       0.50      0.30      0.37       254
#        happy       0.45      0.47      0.46       255
#      neutral       0.47      0.59      0.52       218
#          sad       0.49      0.63      0.55       254
#
#     accuracy                           0.51      1489
#    macro avg       0.50      0.51      0.50      1489
# weighted avg       0.50      0.51      0.50      1489

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.75      0.47      0.58      1103
#      disgust       0.00      0.50      0.00         2
#         fear       0.04      0.23      0.06        40
#        happy       0.17      0.17      0.17       595
#      neutral       0.66      0.25      0.36      1708
#          sad       0.47      0.67      0.55      1084
#     surprise       0.00      0.00      0.00       107
#
#     accuracy                           0.38      4639
#    macro avg       0.30      0.33      0.25      4639
# weighted avg       0.55      0.38      0.42      4639
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
best_model = load('rf_C_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.14      0.47      0.21       345
#      disgust       0.02      0.13      0.04        68
#         fear       0.02      0.02      0.02        50
#        happy       0.15      0.26      0.19       402
#      neutral       0.45      0.05      0.09      1256
#          sad       0.08      0.06      0.07       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.13      2610
#    macro avg       0.12      0.14      0.09      2610
# weighted avg       0.26      0.13      0.11      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    iemocap_feats,
    iemocap['label'],
    test_size=0.2,
    random_state=42,
    stratify=iemocap['label']
)

grid_search_rf = GridSearchCV(rf_pipeline, grid_param, cv=10, n_jobs=-1, verbose=2)
grid_search_rf.fit(X_train, y_train)
print("Best parameters (RF):", grid_search_rf.best_params_) 
print("Best cross-validation score (RF):", grid_search_rf.best_score_)
dump(grid_search_rf.best_estimator_, 'rf_I.joblib')
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  12.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  12.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  12.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   6.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   6.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  13.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   6.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   6.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   6.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   6.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   7.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   7.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   7.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   7.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   7.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  15.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  15.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  15.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  15.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  15.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  15.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  15.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  13.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  13.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  13.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  10.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   3.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   8.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   3.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   7.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   8.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  11.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  12.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  11.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  10.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  10.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   9.4s
# Best parameters (RF): {'rf__max_depth': 20, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}
# Best cross-validation score (RF): 0.6283997043735327
# ['rf_I.joblib']

# %%
best_model = load('rf_I.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.71      0.70      0.70       221
#         fear       0.00      0.00      0.00         8
#        happy       0.54      0.06      0.11       119
#      neutral       0.56      0.77      0.65       342
#          sad       0.66      0.70      0.68       217
#     surprise       0.00      0.00      0.00        21
#
#     accuracy                           0.62       928
#    macro avg       0.41      0.37      0.36       928
# weighted avg       0.60      0.62      0.58       928

# %%
best_model = load('rf_I.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.15      0.71      0.25       345
#      disgust       0.00      0.00      0.00        68
#         fear       0.00      0.00      0.00        50
#        happy       0.19      0.12      0.15       402
#      neutral       0.51      0.30      0.38      1256
#          sad       0.06      0.00      0.01       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.26      2610
#    macro avg       0.13      0.16      0.11      2610
# weighted avg       0.30      0.26      0.24      2610

# %% [markdown]
# ## Logistic Regression

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
logreg_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection1', FeatureSelector(algorithm="algorithm1", L=0.80, dispersion_measure="MAD", similarity_measure="AC")),
    ('scaler2', StandardScaler()),
    ('feature_selection2', FeatureSelector(algorithm="algorithm2", L=0.95, MS=0.75, dispersion_measure="MAD", similarity_measure="AC")),
    ('logreg', LogisticRegression(max_iter=5000)),
])
grid_param = {
    'logreg__C': [0.1, 1, 10],
    'logreg__penalty': ['l2'],
    'logreg__solver': ['lbfgs', 'saga'],
}

X_train, X_test, y_train, y_test = train_test_split(
    emobd_feats,
    emodb['label'],
    test_size=0.2,
    random_state=42,
    stratify=emodb['label']
)
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
grid_search_logreg = GridSearchCV(logreg_pipeline, grid_param, cv=cv, n_jobs=-1, verbose=2)
grid_search_logreg.fit(X_train, y_train)
print("Best parameters (LogReg):", grid_search_logreg.best_params_) 
print("Best cross-validation score (LogReg):", grid_search_logreg.best_score_)
dump(grid_search_logreg.best_estimator_, 'logreg_E_FS.joblib')
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 45 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 44 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 46 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.2s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Best parameters (LogReg): {'logreg__C': 0.1, 'logreg__penalty': 'l2', 'logreg__solver': 'lbfgs'}
# Best cross-validation score (LogReg): 0.7628378378378379
# ['logreg_E_FS.joblib']

# %%
best_model = load('logreg_E_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.84      0.81      0.82        26
#      disgust       0.80      0.89      0.84         9
#         fear       0.93      0.93      0.93        14
#        happy       0.69      0.64      0.67        14
#      neutral       0.88      0.94      0.91        16
#          sad       0.92      0.92      0.92        12
#
#     accuracy                           0.85        91
#    macro avg       0.84      0.85      0.85        91
# weighted avg       0.84      0.85      0.84        91

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.89      0.24      0.38      1103
#      disgust       0.00      0.50      0.00         2
#         fear       0.14      0.03      0.04        40
#        happy       0.21      0.08      0.12       595
#      neutral       0.50      0.00      0.01      1708
#          sad       0.48      0.48      0.48      1084
#     surprise       0.00      0.00      0.00       107
#
#     accuracy                           0.18      4639
#    macro avg       0.32      0.19      0.15      4639
# weighted avg       0.54      0.18      0.22      4639
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
best_model = load('logreg_E_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.17      0.53      0.26       345
#      disgust       0.02      0.18      0.03        68
#         fear       0.02      0.12      0.04        50
#        happy       0.18      0.12      0.14       402
#      neutral       0.49      0.06      0.11      1256
#          sad       0.09      0.10      0.09       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.13      2610
#    macro avg       0.14      0.16      0.10      2610
# weighted avg       0.30      0.13      0.12      2610
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/krazmic/Documents/GitHub/Repos/EmoReA/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    ravdess_feats,
    ravdess['label'],
    test_size=0.2,
    random_state=42,
    stratify=ravdess['label']
)
grid_search_logreg = GridSearchCV(logreg_pipeline, grid_param, cv=10, n_jobs=-1, verbose=2)
grid_search_logreg.fit(X_train, y_train)
print("Best parameters (LogReg):", grid_search_logreg.best_params_) 
print("Best cross-validation score (LogReg):", grid_search_logreg.best_score_)
dump(grid_search_logreg.best_estimator_, 'logreg_R_FS.joblib')
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.5s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.5s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.7s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.6s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.9s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.7s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   1.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   4.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   4.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   5.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   6.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   4.0s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   6.8s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   3.8s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.1s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   6.7s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   5.0s
# Best parameters (LogReg): {'logreg__C': 0.1, 'logreg__penalty': 'l2', 'logreg__solver': 'lbfgs'}
# Best cross-validation score (LogReg): 0.5591010101010101
# ['logreg_R_FS.joblib']

# %%
best_model = load('logreg_R_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.70      0.55      0.62        38
#      disgust       0.53      0.55      0.54        38
#         fear       0.64      0.36      0.46        39
#        happy       0.44      0.56      0.49        39
#      neutral       0.26      0.37      0.30        19
#          sad       0.42      0.44      0.43        39
#     surprise       0.49      0.53      0.51        38
#
#     accuracy                           0.49       250
#    macro avg       0.50      0.48      0.48       250
# weighted avg       0.51      0.49      0.49       250

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       1.00      0.05      0.09      1103
#      disgust       0.00      0.00      0.00         2
#         fear       0.02      0.12      0.04        40
#        happy       0.16      0.13      0.15       595
#      neutral       0.51      0.01      0.02      1708
#          sad       0.27      0.66      0.39      1084
#     surprise       0.13      0.21      0.16       107
#
#     accuracy                           0.19      4639
#    macro avg       0.30      0.17      0.12      4639
# weighted avg       0.51      0.19      0.14      4639

# %%
best_model = load('logreg_R_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.19      0.02      0.04       345
#      disgust       0.03      0.37      0.05        68
#         fear       0.01      0.04      0.01        50
#        happy       0.15      0.27      0.19       402
#      neutral       0.55      0.01      0.03      1256
#          sad       0.09      0.27      0.14       208
#     surprise       0.16      0.03      0.05       281
#
#     accuracy                           0.09      2610
#    macro avg       0.17      0.15      0.07      2610
# weighted avg       0.34      0.09      0.07      2610

# %%
X_train, X_test, y_train, y_test = train_test_split(
    tess_feats,
    tess['label'],
    test_size=0.2,
    random_state=42,
    stratify=tess['label']
)
grid_search_logreg = GridSearchCV(logreg_pipeline, grid_param, cv=10, n_jobs=-1, verbose=2)
grid_search_logreg.fit(X_train, y_train)
print("Best parameters (LogReg):", grid_search_logreg.best_params_) 
print("Best cross-validation score (LogReg):", grid_search_logreg.best_score_)
dump(grid_search_logreg.best_estimator_, 'logreg_T_FS.joblib')
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.2s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.3s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.3s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.5s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.5s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.7s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.7s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.9s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.9s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   3.1s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   3.2s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.1s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.5s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.7s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   8.0s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   7.8s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   8.2s
# Best parameters (LogReg): {'logreg__C': 10, 'logreg__penalty': 'l2', 'logreg__solver': 'saga'}
# Best cross-validation score (LogReg): 0.9714285714285715
# ['logreg_T_FS.joblib']

# %%
best_model = load('logreg_T_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.96      0.99      0.98        80
#      disgust       0.99      0.97      0.98        80
#         fear       0.96      0.97      0.97        80
#        happy       0.94      0.91      0.92        80
#      neutral       1.00      1.00      1.00        80
#          sad       0.99      1.00      0.99        80
#     surprise       0.94      0.93      0.93        80
#
#     accuracy                           0.97       560
#    macro avg       0.97      0.97      0.97       560
# weighted avg       0.97      0.97      0.97       560

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.65      0.04      0.08      1103
#      disgust       0.00      1.00      0.00         2
#         fear       0.01      0.42      0.02        40
#        happy       0.21      0.01      0.02       595
#      neutral       1.00      0.00      0.00      1708
#          sad       0.00      0.00      0.00      1084
#     surprise       0.09      0.10      0.10       107
#
#     accuracy                           0.02      4639
#    macro avg       0.28      0.23      0.03      4639
# weighted avg       0.55      0.02      0.02      4639

# %%
best_model = load('logreg_T_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.17      0.24      0.20       345
#      disgust       0.02      0.44      0.04        68
#         fear       0.02      0.30      0.04        50
#        happy       0.17      0.02      0.04       402
#      neutral       0.00      0.00      0.00      1256
#          sad       0.00      0.00      0.00       208
#     surprise       0.06      0.01      0.02       281
#
#     accuracy                           0.05      2610
#    macro avg       0.06      0.14      0.05      2610
# weighted avg       0.06      0.05      0.04      2610

# %%
X_train, X_test, y_train, y_test = train_test_split(
    crema_d_feats,
    crema_d['label'],
    test_size=0.2,
    random_state=42,
    stratify=crema_d['label']
)
grid_search_logreg = GridSearchCV(logreg_pipeline, grid_param, cv=cv, n_jobs=-1, verbose=2)
grid_search_logreg.fit(X_train, y_train)
print("Best parameters (LogReg):", grid_search_logreg.best_params_) 
print("Best cross-validation score (LogReg):", grid_search_logreg.best_score_)
dump(grid_search_logreg.best_estimator_, 'logreg_C_FS.joblib')
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.[CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
#
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   0.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.0s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.0s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# Alg. 2: Selected 43 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   1.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   2.9s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   4.4s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   5.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   5.5s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   4.2s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   4.1s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   4.7s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 41 features out of 49 total features.
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=   4.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 43 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  11.3s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  12.6s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   5.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  14.2s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  10.7s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  11.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  11.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  12.7s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=   8.9s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  10.8s
# Alg. 1: Selected top 49 features out of 62 total features.
# Alg. 2: Selected 42 features out of 49 total features.
# Best parameters (LogReg): {'logreg__C': 10, 'logreg__penalty': 'l2', 'logreg__solver': 'saga'}
# Best cross-validation score (LogReg): 0.505798883311714
# ['logreg_C_FS.joblib']

# %%
best_model = load('logreg_C_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.72      0.73      0.72       254
#      disgust       0.45      0.41      0.43       254
#         fear       0.48      0.43      0.45       254
#        happy       0.51      0.46      0.48       255
#      neutral       0.49      0.57      0.53       218
#          sad       0.47      0.54      0.51       254
#
#     accuracy                           0.52      1489
#    macro avg       0.52      0.52      0.52      1489
# weighted avg       0.52      0.52      0.52      1489

# %%
y_pred = best_model.predict(iemocap_feats)
print(classification_report(iemocap['label'], y_pred))
plot_confusion_matrix(iemocap['label'], y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.80      0.46      0.59      1103
#      disgust       0.00      0.50      0.00         2
#         fear       0.06      0.20      0.10        40
#        happy       0.18      0.05      0.07       595
#      neutral       0.57      0.51      0.54      1708
#          sad       0.58      0.53      0.55      1084
#     surprise       0.00      0.00      0.00       107
#
#     accuracy                           0.43      4639
#    macro avg       0.31      0.32      0.26      4639
# weighted avg       0.56      0.43      0.48      4639

# %%
best_model = load('logreg_C_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        angry       0.15      0.24      0.18       345
#      disgust       0.03      0.62      0.05        68
#         fear       0.00      0.00      0.00        50
#        happy       0.25      0.06      0.10       402
#      neutral       0.49      0.09      0.16      1256
#          sad       0.08      0.03      0.04       208
#     surprise       0.00      0.00      0.00       281
#
#     accuracy                           0.10      2610
#    macro avg       0.14      0.15      0.08      2610
# weighted avg       0.30      0.10      0.12      2610

# %%
X_train, X_test, y_train, y_test = train_test_split(
    iemocap_feats,
    iemocap['label'],
    test_size=0.2,
    random_state=42,
    stratify=iemocap['label']
)
grid_search_logreg = GridSearchCV(logreg_pipeline, grid_param, cv=10, n_jobs=-1, verbose=2)
grid_search_logreg.fit(X_train, y_train)
print("Best parameters (LogReg):", grid_search_logreg.best_params_) 
print("Best cross-validation score (LogReg):", grid_search_logreg.best_score_)
dump(grid_search_logreg.best_estimator_, 'logreg_I_FS.joblib')
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.5s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.7s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.7s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.8s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   2.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.7s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.7s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.7s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   3.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   3.3s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   3.5s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   3.4s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   3.6s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   3.7s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   4.3s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=lbfgs; total time=   0.7s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   3.9s
# [CV] END logreg__C=0.1, logreg__penalty=l2, logreg__solver=saga; total time=   3.9s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.5s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.8s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.5s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.7s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.8s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=lbfgs; total time=   1.8s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  11.2s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  11.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  12.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  12.5s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  12.6s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  13.6s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  14.6s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  14.7s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  14.4s
# [CV] END logreg__C=1, logreg__penalty=l2, logreg__solver=saga; total time=  15.4s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  28.1s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  25.0s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  34.8s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  33.0s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  30.5s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  33.5s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  32.0s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  32.6s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  33.3s
# [CV] END logreg__C=10, logreg__penalty=l2, logreg__solver=saga; total time=  32.3s
# Best parameters (LogReg): {'logreg__C': 1, 'logreg__penalty': 'l2', 'logreg__solver': 'lbfgs'}
# Best cross-validation score (LogReg): 0.6033410138248849
# ['logreg_I_FS.joblib']

# %%
best_model = load('logreg_I_FS.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
plot_confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.74      0.69      0.72       221
#         fear       0.25      0.12      0.17         8
#        happy       0.52      0.10      0.17       119
#      neutral       0.55      0.76      0.64       342
#          sad       0.65      0.67      0.66       217
#     surprise       0.67      0.10      0.17        21
#
#     accuracy                           0.62       928
#    macro avg       0.56      0.41      0.42       928
# weighted avg       0.62      0.62      0.59       928

# %%
best_model = load('logreg_I_FS.joblib')
y_pred = best_model.predict(meld_feats)
print(classification_report(meld['label'], y_pred))
plot_confusion_matrix(meld['label'], y_pred)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.15      0.67      0.24       345
#      disgust       0.04      0.01      0.02        68
#         fear       0.00      0.00      0.00        50
#        happy       0.18      0.21      0.20       402
#      neutral       0.54      0.18      0.27      1256
#          sad       0.10      0.05      0.07       208
#     surprise       0.25      0.01      0.02       281
#
#     accuracy                           0.21      2610
#    macro avg       0.18      0.16      0.12      2610
# weighted avg       0.34      0.21      0.20      2610

# %% [markdown]
# ## XGBoost

# %%
# grid search XGBoost
from xgboost import XGBClassifier
#label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)   
xgb_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('xgb', XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')),
])
xgb_param = {
    'xgb__n_estimators': [100, 200],
    'xgb__max_depth': [3, 6],
    'xgb__learning_rate': [0.01, 0.1],
}
grid_search_xgb = GridSearchCV(xgb_pipeline, xgb_param, cv=10, n_jobs=-1, verbose=2)
grid_search_xgb.fit(X_train, y_train_enc)
print("Best parameters (XGB):", grid_search_xgb.best_params_) 
print("Best cross-validation score (XGB):", grid_search_xgb.best_score_)
dump(grid_search_xgb.best_estimator_, 'xgb_ERC.joblib')
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:00:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.5s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.7s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.7s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.7s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.7s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.8s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.8s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.5s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.5s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.7s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.8s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.7s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  33.3s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  34.0s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  35.6s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  35.8s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  36.7s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  37.3s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  37.4s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  37.5s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  37.8s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=100; total time=  38.1s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:01:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.5s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.6s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.4s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.3s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.3s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.3s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.3s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.3s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.5s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=100; total time=   7.5s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.2s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.3s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.1s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  14.2s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  15.4s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:02:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  15.5s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  16.6s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  16.7s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  16.6s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=3, xgb__n_estimators=200; total time=  16.7s
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.01, xgb__max_depth=6, xgb__n_estimators=200; total time= 1.2min
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  32.0s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  32.3s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  32.0s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  31.6s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  30.6s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  30.8s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  31.1s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  30.5s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:03:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  31.2s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=100; total time=  31.1s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  54.5s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  54.3s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  47.8s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  46.5s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  47.3s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  46.7s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  44.1s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  43.6s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  44.0s
# [CV] END xgb__learning_rate=0.1, xgb__max_depth=6, xgb__n_estimators=200; total time=  43.7s
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/xgboost/core.py:158: UserWarning: [13:04:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best parameters (XGB): {'xgb__learning_rate': 0.1, 'xgb__max_depth': 6, 'xgb__n_estimators': 200}
# Best cross-validation score (XGB): 0.5065802154703399
# ['xgb_ERC.joblib']

# %%
best_model = load('xgb_ERC.joblib')
y_pred = best_model.predict(X_test)
print(classification_report(y_test_enc, y_pred))
plot_confusion_matrix(y_test_enc, y_pred)
# Out:
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/sofiafernandes/miniconda3/envs/varm/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.36      0.07      0.11       400
#            1       0.26      0.81      0.40       400
#            2       0.66      0.18      0.29       400
#            3       0.20      0.34      0.25       400
#            4       0.26      0.06      0.10       400
#            5       0.36      0.54      0.43       400
#            6       0.00      0.00      0.00       400
#
#     accuracy                           0.29      2800
#    macro avg       0.30      0.29      0.23      2800
# weighted avg       0.30      0.29      0.23      2800

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# **2. eGeMAPS:**
# * **What it is:** eGeMAPS is a carefully selected set of 88 acoustic features designed to capture essential paralinguistic information related to emotion. It's based on extensive research in affective computing and aims for a compact yet informative representation of the speech signal.
# * **Characteristics:**
#     * **Low dimensionality:** 88 features per time frame. This can lead to faster training and potentially require less data for the models to generalize.
#     * **Emotionally relevant:** The features are specifically chosen for their known correlation with emotional states.
#     * **Interpretability:** Some of the features have relatively clear psychoacoustic interpretations (e.g., fundamental frequency, jitter, shimmer, energy-related features, spectral slope).
# * **When to consider it for DL:**
#     * **Smaller datasets:** The lower dimensionality might be advantageous when you have a limited amount of training data, as it reduces the risk of overfitting.
#     * **Focus on paralinguistic cues:** If you believe that the emotional content is primarily conveyed through these higher-level acoustic characteristics.
#     * **Faster experimentation:** The smaller input size can lead to quicker training times, allowing for more rapid iteration.
#
# **2. Full Acoustic Feature Set (librosa - often including MFCCs):**
#
# * **What it is:** This typically involves extracting a wide range of acoustic features using a library like `librosa`. A very common and powerful component of this set is Mel-Frequency Cepstral Coefficients (MFCCs).
# * **Mel-Frequency Cepstral Coefficients (MFCCs):**
#     * **What they are:** MFCCs are a compact representation of the spectral envelope of a speech signal, mimicking the human auditory system's perception of frequencies. They are derived by taking the Fourier transform of short segments of the audio, mapping the powers of these frequencies onto the mel scale (a perceptual scale of pitches), taking the logarithm of these mel-scaled powers, and then taking the discrete cosine transform (DCT) of the list of mel log powers.
#     * **Characteristics:** MFCCs capture the short-term power spectrum of the sound, which is highly relevant for phonetic content and also carries emotional information. The number of MFCCs typically ranges from 13 to 40.
# * **Other features in a "full" set (from librosa):** Besides MFCCs, `librosa` can extract a plethora of other features, including:
#     * **Spectral features:** Spectral centroid, spectral bandwidth, spectral contrast, spectral flatness, spectral roll-off.
#     * **Temporal features:** Zero-crossing rate, root-mean-square (RMS) energy.
#     * **Chromagram:** Representation of the spectral energy distribution over 12 pitch classes.
#     * **And many more.**
# * **Characteristics of the full set:**
#     * **High dimensionality:** Combining MFCCs (e.g., 20-40 coefficients per frame) with other spectral and temporal features can result in a significantly higher-dimensional input compared to GeMAPS.
#     * **Rich information:** This set captures a broader range of acoustic characteristics, potentially including subtle cues that GeMAPS might miss.
#     * **Potentially better performance (with enough data):** With sufficient training data, the richer input can allow deep learning models to learn more complex patterns and achieve higher accuracy.
# * **When to consider it for DL:**
#     * **Larger datasets:** Deep learning models thrive on large amounts of data to learn complex relationships in high-dimensional spaces.
#     * **Potential for higher accuracy:** The comprehensive feature set might capture more nuanced emotional information.
#     * **Flexibility for the model:** The neural network can learn to weigh the importance of different features within the set.
#
# ## Input for Your Deep Learning Architectures: Detailed Explanation
#
# Now, let's specifically address how you would use these features as input for your CNN, RNN, and Hybrid models:
#
# **1. Convolutional Neural Networks (CNNs):**
#
# * **Input format:** CNNs are typically designed to process grid-like data. For audio, this often translates to a 2D representation of the features over time.
# * **How to prepare the input:**
#     * **Frame-based extraction:** Extract your chosen feature set (GeMAPS or the full set) for short, overlapping frames of the audio signal. This will give you a sequence of feature vectors over time.
#     * **Creating the 2D input:** Stack these feature vectors as rows to form a 2D matrix where one dimension represents time frames and the other dimension represents the acoustic features.
#     * **Example:** If you use MFCCs with 20 coefficients and your audio segment is processed into 100 time frames, your input for one audio segment would be a matrix of shape (100, 20).
#     * **Channel dimension:** For CNNs, you often need to add a channel dimension. So, your input shape would become (100, 20, 1). If you were to use something like a spectrogram (which is inherently 2D - frequency x time), you might have multiple channels (e.g., magnitude and phase). However, with MFCCs or GeMAPS, you'll likely start with a single channel.
# * **Considerations:**
#     * **Input shape consistency:** Ensure all your input sequences have the same length or use techniques like padding or truncation to handle variable lengths.
#     * **Normalization/Standardization:** It's crucial to normalize or standardize your features (e.g., using StandardScaler from scikit-learn) before feeding them into the neural network to improve training stability and performance.
#
# **2. Recurrent Neural Networks (RNNs - LSTMs/GRUs):**
#
# * **Input format:** RNNs are designed to process sequential data.
# * **How to prepare the input:**
#     * **Frame-based extraction:** Similar to CNNs, extract your chosen feature set for each time frame.
#     * **Sequential input:** The input for each audio segment will be a sequence of feature vectors.
#     * **Example:** If you use GeMAPS (88 features) and your audio segment has 150 time frames, your input shape for one segment would be (150, 88).
# * **Considerations:**
#     * **Variable sequence lengths:** RNNs can naturally handle variable-length sequences. However, for batch processing, you'll typically need to pad shorter sequences to the length of the longest sequence in the batch. Masking layers can be used to ignore the padded parts.
#     * **Normalization/Standardization:** Again, normalizing or standardizing your features is essential.
#
# **3. Hybrid CNN-RNN:**
#
# * **Input format:** These models typically leverage the strengths of both CNNs for feature extraction and RNNs for sequential modeling.
# * **How to prepare the input:**
#     * **CNN part:** The initial input to the CNN part would be similar to the CNN case – a 2D representation of your chosen features over time (e.g., (time frames, features, channels)).
#     * **Feature maps to sequence:** The CNN layers would learn to extract higher-level spatio-temporal features. The output of the CNN (after flattening or using techniques like global pooling) would then be reshaped into a sequential form to be fed into the RNN layers (e.g., a sequence of feature vectors where each vector represents a summary of a local time-frequency region).
#     * **RNN processing:** The RNN (LSTM or GRU) would then process this sequence of CNN-extracted features to model the temporal dependencies for emotion recognition.
# * **Considerations:**
#     * **Careful design of the CNN output to sequence mapping:** How you transition from the CNN's feature maps to the RNN's input sequence is a crucial design choice.
#     * **Normalization/Standardization:** Apply normalization/standardization to the initial input features.
#
# ## Which Input Should You Choose for DL Experiments?
#
# There's no single "best" answer, and it often depends on your dataset size, the complexity of the emotional cues in your data, and the specific architecture you're using. However, here's a general guideline and some suggestions for your experiments:
#
# * **Start with MFCCs (as part of the full acoustic set):** MFCCs have a strong track record in speech-related tasks, including emotion recognition. They capture crucial information about the spectral envelope that is relevant to both phonetic content and emotional expression.
# * **Experiment with the full acoustic feature set from `librosa`:** This allows the model to potentially learn from a wider range of acoustic cues. Be mindful of the increased dimensionality and the potential need for more data.
# * **Consider GeMAPS as a baseline or for smaller datasets:** If your dataset is relatively small, GeMAPS' lower dimensionality might help prevent overfitting and provide a good starting point.
# * **Don't be afraid to combine:** You could even explore combining GeMAPS with other features (though this wasn't explicitly in your initial plan).
#
# **Recommendations for your experiments:**
#
# Given your setup, I would recommend the following initial DL experiments:
#
# 1.  **CNN with MFCCs:**
#     * Input: 2D representation of MFCCs (time frames x MFCC coefficients x 1 channel).
#     * Rationale: MFCCs are a strong baseline, and CNNs excel at learning local patterns in grid-like data, which can be effective for analyzing the spectral evolution over time.
#
# 2.  **RNN (LSTM or GRU) with MFCCs:**
#     * Input: Sequence of MFCC vectors (time frames x MFCC coefficients).
#     * Rationale: RNNs are designed to capture temporal dependencies in sequential data, which is crucial for understanding the evolution of emotional expression in speech.
#
# 3.  **Hybrid CNN-RNN with MFCCs:**
#     * Input: 2D representation of MFCCs.
#     * Rationale: This architecture can leverage the CNN to extract meaningful local features from the MFCCs and the RNN to model the temporal relationships between these features.
#
# After exploring these with MFCCs, you can then venture into using the full acoustic feature set from `librosa` with these same architectures to see if the richer input leads to improved performance. Finally, you could try GeMAPS, especially if you find that your dataset is limited.
#
# ## Evaluation Strategy: 10-Fold Cross-Validation and GridSearchCV
#
# Your initial thought of using 10-fold cross-validation is a standard and good practice for evaluating the generalization performance of your models.
#
# **GridSearchCV:**
#
# * **Purpose:** GridSearchCV is a technique for hyperparameter tuning. It systematically searches through a predefined set of hyperparameter combinations for your chosen model and evaluates the performance of each combination using cross-validation on your training data.
# * **Integration with 10-fold CV:** You would typically use 10-fold cross-validation *within* each hyperparameter combination being evaluated by GridSearchCV. This ensures a robust estimate of the model's performance for each set of hyperparameters.
# * **Considerations for DL:** GridSearchCV can be computationally expensive, especially for deep learning models with a large number of hyperparameters and long training times. You might consider:
#     * **RandomizedSearchCV:** This is a less exhaustive but often more efficient alternative that samples a fixed number of hyperparameter combinations.
#     * **More focused hyperparameter ranges:** Based on literature or initial pilot experiments, narrow down the ranges of hyperparameters you want to search.
#     * **Early stopping:** Implement early stopping during the training within each cross-validation fold to save time.
#
# **Less on More Expensive Tasks (FER/MER):**
#
# Your intuition about reducing the cross-validation folds or the granularity of the hyperparameter search for more computationally expensive tasks like Facial Emotion Recognition (FER) or Music Emotion Recognition (MER) is correct. These tasks often involve larger input dimensions (e.g., images or longer audio sequences) and more complex models, leading to significantly longer training times. In such cases, you might consider:
#
# * **Fewer cross-validation folds (e.g., 3 or 5).**
# * **A coarser grid of hyperparameters in GridSearchCV or using RandomizedSearchCV.**
# * **Focusing on tuning the most critical hyperparameters.**
#
# For your SER experiments, starting with 10-fold cross-validation combined with GridSearchCV (if computationally feasible) is a good approach to thoroughly evaluate your models and find optimal hyperparameters.
#
# In summary, for your deep learning SER experiments, begin by focusing on **MFCCs** as input for your CNN, RNN, and hybrid models. Experiment with the 2D representation for CNNs and the sequential representation for RNNs. Remember to normalize your features and consider the impact of input dimensionality on your model complexity and data requirements. Good luck with your research!
#
# 1.  **Data Loading and Preprocessing:**
#     * **Load Audio Files:** Use libraries like `librosa` to load your audio files. This will typically give you a 1-dimensional NumPy array representing the audio waveform and the sampling rate.

# %%
import librosa
import numpy as np

def load_audio(file_path, target_sr=16000):
    y, sr = librosa.load(file_path, sr=target_sr)
    return y, sr

audio_path = 'path/to/your/audio.wav'
audio_signal, sampling_rate = load_audio(audio_path)
print(f"Audio shape: {audio_signal.shape}")
print(f"Sampling rate: {sampling_rate}")

# %% [markdown]
# This approach aims to let the network learn the relevant features directly from the waveform, potentially bypassing the need for handcrafted feature extraction like MFCCs or GeMAPS.
#
# * **Resampling (Optional but Recommended):** Standardize the sampling rate across your dataset. This ensures consistent input dimensions for your network. Choose a common sampling rate (e.g., 16000 Hz).
#     * **Normalization:** Normalize the audio signal to a consistent range (e.g., between -1 and 1). This helps with training stability.

# %%
def normalize_audio(audio):
    return audio / np.max(np.abs(audio))

normalized_signal = normalize_audio(audio_signal)
print(f"Normalized audio range: {np.min(normalized_signal):.4f} to {np.max(normalized_signal):.4f}")

# %% [markdown]
# * **Padding or Truncation:** Audio files will likely have variable lengths. Neural networks typically require fixed-size input. You'll need to either:
#     * **Pad:** Add zeros to the end of shorter audio signals to match the length of the longest signal (or a predefined maximum length).
#     * **Truncate:** Cut off longer audio signals to a predefined maximum length.
#     * **Segmentation:** Split longer audio into fixed-length segments. This can also increase your training data.
#
# * **Creating Batches:** When training, you'll feed data to the network in batches. Organize your processed audio signals and their corresponding labels into batches.

# %%
def pad_or_truncate(audio, target_length):
    current_length = len(audio)
    if current_length < target_length:
        padding = np.zeros(target_length - current_length)
        return np.concatenate((audio, padding))
    elif current_length > target_length:
        return audio[:target_length]
    else:
        return audio

target_length_samples = int(2 * sampling_rate) # Example: 2 seconds at 16kHz
processed_signal = pad_or_truncate(normalized_signal, target_length_samples)
print(f"Processed audio shape: {processed_signal.shape}")

# %% [markdown]
# 2.  **Neural Network Architecture:**
#     * **1D Convolutional Neural Networks (1D CNNs):** These are the most common architecture for processing raw audio. 1D convolutional layers can learn temporal patterns directly from the waveform.
#     * **Input Layer:** The input layer of your network will have a shape corresponding to the fixed length of your processed audio signals (e.g., `(target_length_samples, 1)` if you consider it a single channel).
#     * **1D Convolutional Layers:** These layers will slide 1D filters across the time dimension of the audio, learning local temporal features. You'll typically have multiple convolutional layers with increasing numbers of filters to capture increasingly complex patterns.
#     * **Activation Functions:** Use non-linear activation functions (e.g., ReLU) after each convolutional layer.
#     * **Pooling Layers (e.g., MaxPooling1D):** Downsample the temporal dimension, reducing the number of parameters and increasing the receptive field of subsequent layers.
#     * **Flatten Layer:** Flatten the output of the convolutional/pooling layers into a 1D vector before feeding it into fully connected layers.
#     * **Fully Connected (Dense) Layers:** These layers will learn the final mapping from the learned features to the emotion classes.
#     * **Output Layer:** A dense layer with the number of units equal to the number of emotion classes and a softmax activation function for classification.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def create_raw_audio_cnn_model(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv1D(32, kernel_size=5, activation='relu', padding='same'),
        layers.MaxPooling1D(pool_size=2),
        layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'),
        layers.MaxPooling1D(pool_size=2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

target_length = int(2 * 16000)
num_emotions = 8 # Example
input_shape = (target_length, 1) # Single channel for raw audio

raw_audio_model = create_raw_audio_cnn_model(input_shape, num_emotions)
raw_audio_model.summary()

raw_audio_model.compile(optimizer='adam',
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

# Assuming you have your training data (X_train, y_train) prepared
# X_train should have shape (num_samples, target_length) and needs a channel dimension
# X_train = np.expand_dims(X_train, axis=-1)
# raw_audio_model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# %% [markdown]
# 4.  **Training and Evaluation:**
#     * Train your model using your prepared data and labels.
#     * Use an appropriate loss function (e.g., `sparse_categorical_crossentropy` for integer labels or `categorical_crossentropy` for one-hot encoded labels) and an optimizer (e.g., Adam).
#     * Evaluate the model's performance on your test set using appropriate metrics (e.g., accuracy, F1-score).
#     * Use your 10-fold cross-validation strategy (potentially with GridSearchCV for hyperparameter tuning) as you planned.
#
# **Advantages of Using Raw Audio Input:**
#
# * **End-to-end learning:** The network learns features directly tailored to the task, potentially capturing subtle nuances that handcrafted features might miss.
# * **Reduced reliance on domain expertise:** You don't need to manually design features based on acoustic knowledge.
# * **Potential for capturing non-linear relationships:** Deep neural networks can learn complex, non-linear relationships in the raw waveform.
#
# **Challenges and Considerations:**
#
# * **High dimensionality:** Raw audio signals have a very high dimensionality in the time domain. For example, a 1-second audio clip at 16 kHz has 16,000 data points. This can lead to:
#     * **Increased computational cost:** Training can be much slower and require more memory.
#     * **Larger number of parameters:** The network might need more parameters to learn from the high-dimensional input, potentially requiring more training data to avoid overfitting.
# * **Sensitivity to irrelevant variations:** Raw audio can contain variations (e.g., background noise, speaker characteristics) that are not directly related to emotion. The network might learn to focus on these irrelevant details if not trained carefully with sufficient data and regularization.
# * **Long-range dependencies:** Capturing long-range temporal dependencies in the raw waveform can be challenging for simple CNNs. You might need very deep networks or combine them with recurrent layers.
# * **Need for substantial data:** Training deep networks on raw audio effectively often requires a significantly larger dataset compared to using well-engineered features.
#
# **When might raw audio input be beneficial?**
#
# * **Very large datasets:** If you have a massive amount of training data, the network has more opportunities to learn meaningful features.
# * **Tasks where handcrafted features might be limiting:** In cases where the emotional cues are very subtle or complex and not well-captured by traditional features.
# * **Research settings:** For exploring the capabilities of deep learning to automatically learn representations from raw sensory data.
#
# **In your case:**
#
# Given that you are also exploring traditional ML with handcrafted features, it would be a valuable experiment to try a 1D CNN with raw audio input as a comparison. Start with a relatively shallow CNN architecture and see how it performs. Be prepared for potentially longer training times and the need for careful data preprocessing (especially handling variable lengths).
#
# **Conclusion:**
#
# Yes, you can definitely input raw audio into a neural network, primarily using 1D CNNs. However, be aware of the challenges related to high dimensionality and the potential need for large datasets and careful model design. It's a different paradigm compared to using handcrafted features, and the results might vary depending on your specific dataset and the complexity of the emotional cues. Experimentation is key!
